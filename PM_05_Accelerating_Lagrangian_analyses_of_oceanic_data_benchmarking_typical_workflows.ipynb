# %% [markdown]
# # Accelerating Lagrangian analyses of oceanic data: benchmarking typical workflows

# %% [markdown]
# ## Authors
#
# - Author1 = {"name": "Miron, Philippe", "affiliation": "Florida State University", "email": "pmiron@fsu.edu", "orcid": "0000-0002-8520-6221"}
# - Author2 = {"name": "Elipot, Shane", "affiliation": "University of Miami", "email": "selipot@miami.edu", "orcid": "0000-0001-6051-5426 "}
# - Author3 = {"name": "Lumpkin, Rick", "affiliation": "NOAA’s Atlantic Oceanographic and Meteorological Laboratory", "email": "rick.lumpkin@noaa.gov", "orcid": "0000-0002-6690-1704 "}
# - Author4 = {"name": "Dano, Bertrand", "affiliation": "NOAA’s Atlantic Oceanographic and Meteorological Laboratory", "email": "danob@miami.edu", "orcid": ""}

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li>
#             <span>
#                 <a href="#Accelerating-Lagrangian-analyses-of-oceanic-data:-benchmarking-typical-workflows" data-toc-modified-id="Accelerating Lagrangian analyses of oceanic data: benchmarking typical workflows">
#                     <span class="toc-item-num">1.&nbsp;</span>Accelerating Lagrangian analyses of oceanic data: benchmarking typical workflows
#                 </a>
#             </span>
#             <ul class="toc-item">
#                 <li>
#                     <span>
#                         <a href="#Author(s)" data-toc-modified-id="Author(s)"><span class="toc-item-num">1.1&nbsp;</span>Author(s)</a>
#                     </span>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span>
#                 <a href="#Table-of-Content" data-toc-modified-id="Table of Content"> <span class="toc-item-num">2.&nbsp;</span>Table of Content </a>
#             </span>
#         </li>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Purpose" data-toc-modified-id="Purpose"><span class="toc-item-num">2.1&nbsp;</span>Purpose</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Technical-contributions" data-toc-modified-id="Technical-contributions"><span class="toc-item-num">2.2&nbsp;</span>Technical contributions</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Methodology" data-toc-modified-id="Methodology"><span class="toc-item-num">2.4&nbsp;</span>Methodology</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Results" data-toc-modified-id="Results"><span class="toc-item-num">2.4&nbsp;</span>Results</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Funding" data-toc-modified-id="Funding"><span class="toc-item-num">2.5&nbsp;</span>Funding</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Keywords" data-toc-modified-id="Keywords"><span class="toc-item-num">2.6&nbsp;</span>Keywords</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Citation" data-toc-modified-id="Citation"><span class="toc-item-num">2.7&nbsp;</span>Citation</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Suggested-next-steps" data-toc-modified-id="Suggested-next-steps"><span class="toc-item-num">2.8&nbsp;</span>Suggested next steps</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Acknowledgements" data-toc-modified-id="Acknowledgements.11"><span class="toc-item-num">2.9&nbsp;</span>Acknowledgements</a>
#                 </span>
#             </li>
#         </ul>
#         <li>
#             <span>
#                 <a href="#Setup" data-toc-modified-id="Setup"><span class="toc-item-num">3.&nbsp;</span>Setup</a>
#             </span>
#         </li>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Library-import" data-toc-modified-id="Library-import"><span class="toc-item-num">3.1&nbsp;</span>Library import</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Local-library-import" data-toc-modified-id="Local-library-import"><span class="toc-item-num">3.2&nbsp;</span>Local library import</a>
#                 </span>
#             </li>
#         </ul>
#         <li>
#             <span>
#                 <a href="#Data-Overview" data-toc-modified-id="Data Overview"><span class="toc-item-num">4.&nbsp;</span>Data Overview</a>
#             </span>
#         </li>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Individual-netCDFs" data-toc-modified-id="Individual netCDFs"><span class="toc-item-num">4.1&nbsp;</span>Individual netCDFs</a>
#                 </span>
#             </li>
#             <ul class="toc-item">
#               <li>
#                   <span>
#                       <a href="#Dimensions" data-toc-modified-id="Dimensions"><span class="toc-item-num">4.1.1&nbsp;</span>Dimensions</a>
#                   </span>
#               </li>
#               <li>
#                   <span>
#                       <a href="#Variables" data-toc-modified-id="Variables"><span class="toc-item-num">4.1.2&nbsp;</span>Variables</a>
#                   </span>
#               </li>
#             </ul>
#             <li>
#                 <span>
#                     <a href="#Ragged-Array" data-toc-modified-id="Ragged Array"><span class="toc-item-num">4.2&nbsp;</span>Ragged Array</a>
#                 </span>
#             </li>
#         </ul>
#         <li>
#         <span>
#             <a href="#Complete-GDP-Dataset" data-toc-modified-id="Complete GDP Dataset"><span class="toc-item-num">5.&nbsp;</span>Complete GDP Dataset</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Bench-test-1:-Geographical-binning-of-any-variable" data-toc-modified-id="Bench test 1: Geographical binning of any variable"><span class="toc-item-num">5.1&nbsp;</span>Bench test 1: Geographical binning of any variable</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Bench-test-2:-Extract-a-given-region" data-toc-modified-id="Bench test 2: Extract a given region"><span class="toc-item-num">5.2&nbsp;</span>Bench test 2: Extract a given region</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Bench-test-3:-Single-statistics-per-trajectory" data-toc-modified-id="Bench test 3: Single statistics per trajectory"><span class="toc-item-num">5.3&nbsp;</span>Bench test 3: Single statistics per trajectory</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#         <li>
#         <span>
#             <a href="#Operation-per-trajectory" data-toc-modified-id="Operation per trajectory"><span class="toc-item-num">6.&nbsp;</span>Operation per trajectory</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Applying-operation-per-trajectory-(per-chunks)-using-map_blocks-and-the-more-versatile-apply_ufunc" data-toc-modified-id="## Applying operation per trajectory (per chunks) using `map_blocks` and the more versatile `apply_ufunc`"><span class="toc-item-num">6.1&nbsp;</span>Applying operation per trajectory (per chunks) using `map_blocks` and the more versatile `apply_ufunc`</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#apply_ufunc" data-toc-modified-id="apply_ufunc"><span class="toc-item-num">6.2&nbsp;</span>apply_ufunc</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#         <li>
#         <span>
#             <a href="#II.-Pandas" data-toc-modified-id="II. Pandas"><span class="toc-item-num">7.&nbsp;</span>II. Pandas</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Bench-test-1:-Geographical-binning-of-any-variable" data-toc-modified-id="Bench test 1: Geographical binning of any variable"><span class="toc-item-num">7.1&nbsp;</span>Bench test 1: Geographical binning of any variable</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Bench-test-2:-Extract-a-given-region" data-toc-modified-id="Bench test 2: Extract a given region"><span class="toc-item-num">7.2&nbsp;</span>Bench test 2: Extract a given region</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Bench-test-3:-Single-statistics-per-trajectory" data-toc-modified-id="Bench test 3: Single statistics per trajectory"><span class="toc-item-num">7.3&nbsp;</span>Bench test 3: Single statistics per trajectory</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#         <li>
#         <span>
#             <a href="#III.-Awkward-arrays" data-toc-modified-id="III. Awkward arrays"><span class="toc-item-num">8.&nbsp;</span>III. Awkward arrays</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Bench-test-1:-Geographical-binning-of-any-variable" data-toc-modified-id="Bench test 1: Geographical binning of any variable"><span class="toc-item-num">8.1&nbsp;</span>Bench test 1: Geographical binning of any variable</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Bench-test-2:-Extract-a-given-region" data-toc-modified-id="Bench test 2: Extract a given region"><span class="toc-item-num">8.2&nbsp;</span>Bench test 2: Extract a given region</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Bench-test-3:-Single-statistics-per-trajectory" data-toc-modified-id="Bench test 3: Single statistics per trajectory"><span class="toc-item-num">8.3&nbsp;</span>Bench test 3: Single statistics per trajectory</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Numba" data-toc-modified-id="Numba"><span class="toc-item-num">8.4&nbsp;</span>Numba</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# ## Purpose
#
# For data, “Lagrangian” refers to oceanic and atmosphere information acquired by observing platforms drifting with the flow they are embedded within, but also more broadly refers to the data originating from uncrewed platforms, vehicles, and animals that gather data along their unrestricted but complicated paths. Because such paths traverse both spatial and temporal dimensions, Lagrangian data often convolve spatial and temporal information that cannot always and readily be organized, cataloged, and stored in common data structures and file formats with the help of common libraries and standards. As such, for both data generators and data users, Lagrangian data present challenges that the [CloudDrift](https://github.com/Cloud-Drift) project aims to overcome.
#
# This notebook consists of systematic comparisons and evaluations of workflows for Lagrangian data, using as a basis the velocity and sea surface temperature dataset emanating from the drifting buoys of the [Global Drifter Program](https://www.aoml.noaa.gov/phod/gdp/). Specifically, we consider the interplay between diverse storage file formats ([NetCDF](https://www.unidata.ucar.edu/software/netcdf/), [Parquet](https://github.com/apache/parquet-format)) and the data structure associated with common existing libraries in Python ([xarray](https://docs.xarray.dev/en/stable/), [pandas](https://pandas.pydata.org), and [awkward](https://awkward-array.org/quickstart.html)) in order to test their adequacies for performing three common Lagrangian tasks: (i) binning of a variable on an Eulerian grid (e.g. mean temperature map); (ii) extracting data within given geographical and/or temporal windows; and (iii) analyses per trajectory (e.g. single statistics, Fast Fourier Transforms). Because the CloudDrift project aims at accelerating the use of Lagrangian data for atmospheric, oceanic, and climate sciences, we hope that this notebook will incite the community of users to eventually test it on their own platform and thus provide us with feedback on its ease of use and the intuitiveness of the proposed methods and guide future developments.
#
# ## Technical contributions
# Summarize the central contributions of the notebook (libraries created, scientific analysis demonstrated, etc.), as a bulleted list, with one or more bullets.
#
# -
#
# ## Methodology
# Quickly describe assumptions and processing steps. Include URLs as necessary.
#
# Most cells in this notebook are markdown cells. They describe the expected content of the notebook, steps for formatting and sumitting notebooks, and relevant technologies. The proposed structure and procedures are based on community input and literature (see References)
#
# You can use this template as a visual guide, or configure your Jupyter installation such that every notebook opens with this template, in either short of long version. To enable opening notebooks with this template, see instructions for using the Template nbextension, in the Data Processing section.
#
# Markdown headings are automatically numbered and organized into a Table of Contents (ToC) using the toc2 nbextenion. See  instructions in the Data Processing section.
#
# ## Results
# Describe and comment on the most important results. Include images and URLs as necessary.
#
# This template presents the general structure of notebooks expected by EarthCube, along with recommendations for additional resources to be created to ensure that the notebook is easy to re-use.
#
# ## Funding
#
# - Award1 = {"agency": "NSF EarthCube", "award_code": "2126413", "award_URL": "[https://www.nsf.gov/awardsearch/showAward?AWD_ID=2126413](https://www.nsf.gov/awardsearch/showAward?AWD_ID=2126413)"}
#
# ## Keywords
# Include up to 5 keywords, using the template below.
#
# keywords=["lagrangian", "drifters", "data structures", "workflow tasks", "benchmarks"]
#
# ## Citation
#
# P. Miron, S. Elipot, R. Lumpkin and B. Dano, Accelerating Lagrangian analysis of oceanic data: benchmarking typical workflows, 2022, 2022 EarthCube Annual Meeting, Accessed X/Y/2022 at [https://github.com/Cloud-Drift/earthcube-meeting-2022](https://github.com/Cloud-Drift/earthcube-meeting-2022)
#
# ## Suggested next steps
# State suggested next steps, based on results obtained in this notebook. This section is optional.
#
# ## Acknowledgements
#
# Include any relevant acknowledgements, apart from funding (which was in section 1.6)
#
# This notebook template extends the original notebook template provided with the jupytemplate extension [5]. It is a result of collaboration between the TAC Working Group and the EarthCube Office.
#
# The template is licensed under a [Creative Commons Attribution 4.0 International License](http://creativecommons.org/licenses/by/4.0/).

# %% [markdown]
# # Setup
#
# ## Library import

# %%
# Data manipulation
import numpy as np
import xarray as xr
import pandas as pd
import awkward as ak
from scipy import stats

# others
from os.path import isfile, join
from datetime import datetime
import dask
import numba as nb
import functools

# retrieve data
import urllib.request

# visualization
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable

# Autoreload extension
if 'autoreload' not in get_ipython().extension_manager.loaded:
    # %load_ext autoreload
    
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Local library import

# %%
# Include local library paths
import sys
# sys.path.append('path/to/local/lib') # uncomment and fill to import local libraries

# import local libraries
from preprocess import create_ragged_array

# %% [markdown]
# # Data Overview
#
# The first goal of the notebook is to present the current format of the [Global Drifter Program (GDP)](https://www.aoml.noaa.gov/phod/gdp/) dataset, and its transformation into a single archive where each variable is stored in an ragged fashion.
#
# The GDP produces two interpolated datasets of drifter position, velocity and sea surface temperature from more than 20,000 drifters that have been released since 1979. One dataset is at 6-hour resolution ([Hansen and Poulain 1996](http://dx.doi.org/10.1175/1520-0426(1996)013<0900:QCAIOW>2.0.CO;2)) and the other one is at hourly resolution ([Elipot et al. 2016](http://dx.doi.org/10.1002/2016JC011716)). The files, one per drifter identified by its unique identification number (ID), are updated on a quarterly basis and are available via the FTP website of GDP Data Assembly Center.
#
# We can download a few examples from the hourly dataset to explore the format of the data.

# %%
# download some data by picking a few ID numbers
list_id = [101143, 101144, 101509, 101510, 101511]

input_url = (
    "ftp://ftp.aoml.noaa.gov/phod/pub/lumpkin/hourly/"
    "v2.00/netcdf/"
)

folder =  'data/raw/'  # output folder
files = []
for i in list_id:
    file = f'drifter_{i}.nc'
    url = join(input_url, file)
    
    if not isfile(join(folder, file)):
        req = urllib.request.urlretrieve(url, join(folder, file))
    
    # saved path to file
    files.append(join(folder, file))

# %% [markdown]
# ## Individual netCDFs
# [more description is needed here]
# ### Dimensions
#
# - `['traj']`: 1, one trajectory per file
# - `['obs']`: X, with X the number of observations along the trajectory
#
# ### Variables
#
# There are 20 variables measured (or postprocessed) along the trajectory, their dimension is `['traj', 'obs']`. Naturally, metadata such as: the date of deployment, the type of buoy, etc., are constant along the trajectory and are dimension `['traj']`.

# %%
ds = xr.open_dataset(files[0], decode_times=False)
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (traj: 1, obs: 417)
# Dimensions without coordinates: traj, obs
# Data variables: (12/33)
#     ID                (traj) |S10 ...
#     rowsize           (traj) int32 ...
#     WMO               (traj) float64 ...
#     expno             (traj) float64 ...
#     deploy_date       (traj) float32 ...
#     deploy_lat        (traj) float64 ...
#     ...                ...
#     err_sst           (traj, obs) float64 ...
#     err_sst1          (traj, obs) float64 ...
#     err_sst2          (traj, obs) float64 ...
#     flg_sst           (traj, obs) float64 ...
#     flg_sst1          (traj, obs) float64 ...
#     flg_sst2          (traj, obs) float64 ...
# Attributes: (12/72)
#     title:                      Global Drifter Program hourly drifting buoy c...
#     id:                         Global Drifter Program ID 101143
#     location_type:              Argos
#     wmo_platform_code:          1300915
# ...

# %% [markdown]
# ## Ragged Array
#
# In the GDP dataset, the number of observations varies from `len(['obs'])=13` to `len(['obs'])=66417`. Because of this, it is highly unefficient to create a bidimensional datastructure `['traj', 'obs']`, comonly used in numerical Lagrangian Ocean Analysis toolbox such as [Ocean Parcels](https://oceanparcels.org/). For this, reason we combine the data from the individual netCDFs files into a [*contiguous ragged array*](https://cfconventions.org/cf-conventions/cf-conventions.html#_contiguous_ragged_array_representation). The preprocessing tools (`preprocess.py`) also converts some of the Metadata initially stored as attributes in the individual netCDFs. The final structure contains 21 `vars['obs']` and 38 `vars['traj']`.

# %%
# using the previously downloaded files
ds = create_ragged_array(files).to_xarray()
ds
# Out:
# test
# 5/5
# <xarray.Dataset>
# Dimensions:                (traj: 5, obs: 10345)
# Coordinates:
#     ID                     (traj) int64 101143 101144 101509 101510 101511
#     longitude              (obs) float32 -17.74 -17.75 -17.74 ... -38.92 -38.94
#     latitude               (obs) float32 14.75 14.76 14.77 ... 33.66 33.66 33.66
#     time                   (obs) datetime64[ns] 2012-03-15T22:00:00 ... 2012-...
#     ids                    (obs) int64 101143 101143 101143 ... 101511 101511
# Dimensions without coordinates: traj, obs
# Data variables: (12/54)
#     rowsize                (traj) int64 417 2005 1970 1307 4646
#     location_type          (traj) bool False False False False False
#     WMO                    (traj) int32 1300915 1300941 5200592 5300569 4100556
#     expno                  (traj) int32 9325 9325 9325 9325 6129
#     deploy_date            (traj) datetime64[ns] 2012-03-15 ... 2012-05-27
# ...

# %% [markdown]
# In the combined `xarray.Dataset`, the data from the five trajectories are stored one after the other along the `obs` dimension. The size of each trajectory is stored in the `rowsize` variable.

# %%
ds.rowsize
# Out:
# <xarray.DataArray 'rowsize' (traj: 5)>
# array([ 417, 2005, 1970, 1307, 4646])
# Coordinates:
#     ID       (traj) int64 101143 101144 101509 101510 101511
# Dimensions without coordinates: traj
# Attributes:
#     long_name:  Number of observations per trajectory
#     units:      -

# %% [markdown]
# The structure of a ragged array is slightly more complex than a two dimensional array but has several advantages:
# - one file for the complete dataset and less storage space than a 2d matrix
# - from the `rowsize` variable it is possible to subset the data per trajectory
# - efficient to perform reduce operation on the full dataset since the data is stored in a continous array.

# %%
del ds

# %% [markdown]
# # Complete GDP Dataset
# We have to find a way to put this in a binder where we can store such massive files... or we could also download ~100-200 files and perform the same steps but with smaller files. @philippemiron: so what is the solution now with pangeo? We need to figure this out

# %%
from dask.distributed import Client
# is this portable? I had to manually enter a cluster address. Is it necessary? later it crashed for me with 2 workers on my laptop
#client = Client("tcp://127.0.0.1:54883")

# %%
path_gdp = 'data/gdp_v2.00.nc'
ds = xr.open_dataset(path_gdp, chunks={}) # chunks={} to automatically select chunks size

# %% [markdown]
# The package [xarray](https://docs.xarray.dev/en/stable/) provides an html interface that allows us to quickly scroll to the variable of the `xr.Dataset`, look at its attributes, and get information about the chunk size and the underlying data structure.

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (traj: 17324, obs: 165754333)
# Coordinates:
#     ID                     (traj) int64 dask.array<chunksize=(17324,), meta=np.ndarray>
#     longitude              (obs) float32 dask.array<chunksize=(165754333,), meta=np.ndarray>
#     latitude               (obs) float32 dask.array<chunksize=(165754333,), meta=np.ndarray>
#     time                   (obs) datetime64[ns] dask.array<chunksize=(165754333,), meta=np.ndarray>
#     ids                    (obs) int64 dask.array<chunksize=(165754333,), meta=np.ndarray>
# Dimensions without coordinates: traj, obs
# Data variables: (12/54)
#     rowsize                (traj) int64 dask.array<chunksize=(17324,), meta=np.ndarray>
#     location_type          (traj) bool dask.array<chunksize=(17324,), meta=np.ndarray>
#     WMO                    (traj) int32 dask.array<chunksize=(17324,), meta=np.ndarray>
#     expno                  (traj) int32 dask.array<chunksize=(17324,), meta=np.ndarray>
# ...

# %% [markdown]
# ## Bench test 1: Geographical binning of any variable
# Bins statistic of kinetic energy of all drifters of the dataset.

# %%
# %%time

lon = np.linspace(-180, 180, 360*2)
lat = np.linspace(-90, 90, 180*2)

ret = stats.binned_statistic_2d(ds.longitude, 
                                ds.latitude, 
                                0.5*np.sqrt(np.power(ds.ve, 2) + np.power(ds.vn, 2)), # KE
                                statistic=np.nanmean, 
                                bins=[lon, lat])
# Out:
# CPU times: user 1min 58s, sys: 9.2 s, total: 2min 7s
# Wall time: 2min 8s

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid') # what is that?
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,aspect='equal')
pcm = ax.pcolormesh(x_c, y_c, ret.statistic.T, vmin=0, vmax=0.5)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.02, axes_class=plt.Axes)
fig.colorbar(pcm, cax=cax);
# here we need a geographical projection, better axis labels and a label on the colorbar

# %% [markdown]
# ## Bench test 2: Extract a given region

# %%
def retrieve_region(ds, lon: list = None, lat: list = None, time: list = None):
    '''

    :param lon:
    :param lat:
    :param time:
    :return:
    '''
    mask = np.ones(ds.dims['obs'], dtype='bool')

    if lon:
        mask &= (ds.coords['longitude'] >= lon[0]).values
        mask &= (ds.coords['longitude'] <= lon[1]).values

    if lat:
        mask &= (ds.coords['latitude'] >= lat[0]).values
        mask &= (ds.coords['latitude'] <= lat[1]).values

    if time:
        mask &= (ds.coords['time'] >= np.datetime64(time[0])).values
        mask &= (ds.coords['time'] <= np.datetime64(time[1])).values

    mask_id = np.in1d(ds.ID, np.unique(ds.ids[mask]))
    ds_subset = ds.isel(obs=np.where(mask)[0], traj=np.where(mask_id)[0])

    return ds_subset.compute(), mask

# %%
# %%time
# we need to record the time for benchmarking in the end
lon = [-98, -78]
lat = [18, 31]
day0 = "%sZ" % datetime(2015,1,1).isoformat()
day1 = "%sZ" % datetime(2020,12,31).isoformat()
time = [day0, day1]
ds_subset, m = retrieve_region(ds, lon, lat, time)
# Out:
# /var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_19179/1398817074.py:20: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   mask &= (ds.coords['time'] >= np.datetime64(time[0])).values
# /var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_19179/1398817074.py:21: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   mask &= (ds.coords['time'] <= np.datetime64(time[1])).values
# CPU times: user 16.7 s, sys: 31.4 s, total: 48.1 s
# Wall time: 47.6 s

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,aspect='equal')
# need projection, better labels, thiner trajectory lines.
s = ax.scatter(ds_subset.longitude, ds_subset.latitude, 
               s=0.5, c=ds_subset.sst-273.15, 
               cmap='inferno')

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.02, axes_class=plt.Axes)
fig.colorbar(s, cax=cax);

# %% [markdown]
# ## Bench test 3: Single statistics per trajectory

# %%
# traj_idx[i] contains starting index of the data for the i trajectory
traj_idx = np.insert(np.cumsum(ds.rowsize.values), 0, 0) # this is important, should we highlight this?

# %%
# we can retrive the data of a trajectory with isel
i = 1000
ds.isel({'obs': slice(traj_idx[i], traj_idx[i+1]), 'traj': i}).compute()
# Out:
# <xarray.Dataset>
# Dimensions:                (obs: 23601)
# Coordinates:
#     ID                     int64 114578
#     longitude              (obs) float32 144.8 144.8 144.8 ... 100.7 100.7 100.7
#     latitude               (obs) float32 29.87 29.86 29.85 ... 7.094 7.097 7.099
#     time                   (obs) datetime64[ns] 2014-06-25 ... 2017-03-04T08:...
#     ids                    (obs) int64 114578 114578 114578 ... 114578 114578
# Dimensions without coordinates: obs
# Data variables: (12/54)
#     rowsize                int64 23601
#     location_type          bool False
#     WMO                    int32 2100903
#     expno                  int32 9325
#     deploy_date            datetime64[ns] 2014-06-24
#     deploy_lon             float32 145.0
#     ...                     ...
#     err_sst                (obs) float32 0.023 0.015 0.015 ... 0.015 0.013 nan
#     err_sst1               (obs) float32 0.052 0.034 0.023 ... 0.022 0.03 nan
# ...

# %%
# and perform mean() on a set of variables
s_var = ['ve', 'vn', 'gap', 'err_lat', 'err_lon', 'sst', 'sst1', 'sst2', 'err_sst', 'err_sst1', 'err_sst2']
ds.isel({'obs': slice(traj_idx[i], traj_idx[i+1]), 'traj': i})[s_var].mean().compute()
# Out:
# <xarray.Dataset>
# Dimensions:   ()
# Coordinates:
#     ID        int64 114578
# Data variables:
#     ve        float32 -0.05506
#     vn        float32 -0.03076
#     gap       float32 7.982e+03
#     err_lat   float32 0.003078
#     err_lon   float32 0.004307
#     sst       float32 298.5
#     sst1      float32 298.5
#     sst2      float32 0.002437
#     err_sst   float32 0.03603
#     err_sst1  float32 0.0122
#     err_sst2  float32 0.03238

# %% [markdown]
# # Operation per trajectory

# %% [markdown]
# For this type of operations, it is more efficient to reload the dataset by settings the chunks equal to the dimensions of the trajectory.

# %%
rowsize = ds.rowsize.values
ds.close()

# align chunks of the dask array with the trajectories
chunk_settings = {'obs': tuple(rowsize.tolist())}
ds = xr.open_dataset(path_gdp, chunks=chunk_settings)

# %% [markdown]
# We can see that the variables, such as the longitude, are splitted into 17324 Chunks (with a maximum size of 66417)

# %%
ds.longitude
# Out:
# <xarray.DataArray 'longitude' (obs: 165754333)>
# dask.array<open_dataset-c5a714c587bd7545548cd35998f081ealongitude, shape=(165754333,), dtype=float32, chunksize=(66417,), chunktype=numpy.ndarray>
# Coordinates:
#     longitude  (obs) float32 dask.array<chunksize=(417,), meta=np.ndarray>
#     latitude   (obs) float32 dask.array<chunksize=(417,), meta=np.ndarray>
#     time       (obs) datetime64[ns] dask.array<chunksize=(417,), meta=np.ndarray>
#     ids        (obs) int64 dask.array<chunksize=(417,), meta=np.ndarray>
# Dimensions without coordinates: obs
# Attributes:
#     long_name:  Longitude
#     units:      degrees_east

# %% [markdown]
# Naturally, now loading a trajectory always require loading one chunk.

# %%
# and loading one variable for a trajectory only requires 1 chunk
i = 5252
ds.longitude.isel({'obs': slice(traj_idx[i], traj_idx[i+1])})
# Out:
# <xarray.DataArray 'longitude' (obs: 1093)>
# dask.array<getitem, shape=(1093,), dtype=float32, chunksize=(1093,), chunktype=numpy.ndarray>
# Coordinates:
#     longitude  (obs) float32 dask.array<chunksize=(1093,), meta=np.ndarray>
#     latitude   (obs) float32 dask.array<chunksize=(1093,), meta=np.ndarray>
#     time       (obs) datetime64[ns] dask.array<chunksize=(1093,), meta=np.ndarray>
#     ids        (obs) int64 dask.array<chunksize=(1093,), meta=np.ndarray>
# Dimensions without coordinates: obs
# Attributes:
#     long_name:  Longitude
#     units:      degrees_east

# %% [markdown]
# ## Applying operation per trajectory (per chunks) using `map_blocks` and the more versatile `apply_ufunc`

# %% [markdown]
# For example, a function that calculates the `mean()`, `min()`, and `max()` of an array `x`. When mapped per trajectory (per blocks or chunks), the results will be combined as such: `[mean_traj_1, min_traj_1, max_traj_1, mean_traj_2, min_traj_2, max_traj_2, ..., mean_traj_n, min_traj_n, max_traj_n]` resulting in an `numpy array` 3 times as long.

# %% [markdown]
# The function is applied to each chunks/blocks here using `map_blocks()`. Note that this requires loading 17324 chunks and applying the operation.

# %%
# %%time
# can we separate the cell between function definition and function application? and keep track of time
def func(x):
    return np.array([np.nanmean(x), np.nanmin(x), np.nanmax(x)])

stats_traj = ds.ve.data.map_blocks(func).compute() # apply the variable ve: eastward velocity

assert(len(stats_traj) == 3 * ds.dims['traj']) # three times the number of traj
# Out:
# CPU times: user 15.2 s, sys: 4.52 s, total: 19.7 s
# Wall time: 15.2 s

# %%
stats_traj[:3]
# Out:
# array([ 0.05867722, -0.2676    ,  0.3621    ], dtype=float32)

# %% [markdown]
# ## `apply_ufunc`

# %% [markdown]
# Similarly, one can use `apply_ufunc` to map a function per chunks. The function is a bit more complex, but gives more flexibility to handle the input/output format of the function.

# %% [markdown]
# In this first example, the Eastward velocity is passed by chunk to the function which will calculate the anomaly per trajectory.
#
# - *Note 1*: the input and output sizes are not modified.
# - *Note 2*: you must passed `ds.ve.data` (which retrieves the underlying dask array) to the function

# %%
# %%time
# we need more explanation, and a better visualization of the results
def per_chunk_stats(array):
    # MUST return an array (https://github.com/dask/dask/issues/8822)
    return array.map_blocks(lambda x: x-np.nanmean(x), chunks=array.chunks)

xr.apply_ufunc(
    per_chunk_stats,
    ds.ve.data,  # .data to retrieve the underlying chunked dask array
    input_core_dims=[['obs']],
    output_core_dims=[['obs']],
    dask='allowed'
).compute()
# Out:
# CPU times: user 13.8 s, sys: 4.65 s, total: 18.5 s
# Wall time: 14.7 s
# array([-0.08717722, -0.00737722,  0.00192278, ..., -0.6336789 ,
#        -0.6049789 , -0.61197895], dtype=float32)

# %% [markdown]
# This second example calculates the `mean()` per trajectory. This means that for our datasets consisting of 17324 chunks, the output will have 17324 values or 1 value per chunk.

# %%
# %%time

def per_chunk_mean(array):
    nchunks = len(array.chunks[0])
    output_chunks = ([1] * nchunks,) # 1 value per chunk
    return array.map_blocks(lambda x: np.nanmean(x, keepdims=True), chunks=output_chunks)

xr.apply_ufunc(
    per_chunk_mean,
    ds.ve.data,
    input_core_dims=[['obs']],  # input dimension to the per_block function
    output_core_dims=[['obs']], # output still has one dimension
    exclude_dims=set(['obs']),  # size of x changes so it has to be in the exclude_dims param
    dask='allowed',
).compute()
# Out:
# CPU times: user 13.6 s, sys: 5.42 s, total: 19 s
# Wall time: 15.4 s
# array([ 0.05867722, -0.00064603, -0.17721245, ...,  0.20617656,
#        -0.00078386, -0.02242104], dtype=float32)

# %% [markdown]
# A last example, we calculate `fft` on `u+vi` which is a similar step involved in the calculation of *rotary spectrum*. The combinations of `apply_ufunc` and `map_blocks` is pretty powerful and can serve as templates for most processing applied per trajectory.

# %%
#ds['cmp_uv'].data # ds has no 'cmp_uv' variable?? let's call that cv
ds = ds.assign(cv=ds['ve'] + 1j * ds['vn'])
ds.cv
# Out:
# <xarray.DataArray 'cv' (obs: 165754333)>
# dask.array<add, shape=(165754333,), dtype=complex64, chunksize=(66417,), chunktype=numpy.ndarray>
# Coordinates:
#     longitude  (obs) float32 dask.array<chunksize=(417,), meta=np.ndarray>
#     latitude   (obs) float32 dask.array<chunksize=(417,), meta=np.ndarray>
#     time       (obs) datetime64[ns] dask.array<chunksize=(417,), meta=np.ndarray>
#     ids        (obs) int64 dask.array<chunksize=(417,), meta=np.ndarray>
# Dimensions without coordinates: obs

# %%
# %%time
# save output of time? and output?
def per_chunk_fft(array):
    return array.map_blocks(lambda x: np.fft.fft(x), chunks=array.chunks)

xr.apply_ufunc(
    per_chunk_fft,
    ds['cv'].data,
    input_core_dims=[["obs"]],  # input dimension to the per_block function
    output_core_dims=[["obs"]],  # output still has one dimension
    dask='allowed'
).compute()
# Out:
# CPU times: user 40.3 s, sys: 13 s, total: 53.2 s
# Wall time: 26.7 s
# array([ 24.46840008+18.70980014j,  37.57112095 +1.47150771j,
#         23.8163065  -0.69824325j, ..., -28.21330646 -8.76757567j,
#        -30.42217431 -5.0045694j , -19.64997094+29.92176195j])

# %% [markdown]
# The second goal of the notebook is to represent similar workflow with other data science libraries. The following sections present similar Lagrangian tasks using Pandas and Awkward array.

# %%
del ds

# %% [markdown]
# At this stage it is necessary to clear the memory (RAM) of the python process because in the next step, the data are fully loaded in memory by using Pandas.

# %% [markdown]
# # II. Pandas
#
# The netCDF has two dimensions `[traj]` and `[obs]`, so it can't be read into a two-dimensional  (rows/columns) `pandas.DataFrame()`. Here, we are loading a parquet file, which was extracted from the previous netCDF. It contains all `variables[obs]`, and was generated as follow `ds.drop_dims('traj').to_pandas().to_parquet('../data/process/gdp_v2.00-obs.parquet')`.

# %%
# %%time
df = pd.read_parquet("data/gdp_v2.00-obs.parquet")  # contains the vars[obs]
# Out:
# CPU times: user 50.6 s, sys: 1min 22s, total: 2min 12s
# Wall time: 41.4 s

# %% [markdown]
# The pandas representation is a simple two dimensional array, with the columns the different variables of the dataset. @philippemiron: but no more metadata?

# %%
df.head() # it took a super long time to get this displayed. And tons of memory wrangling.
# Out:
#          ve      vn     gap  err_lat  err_lon  err_ve  err_vn  drogue_status  \
# obs
# 0   -0.0285  0.3101  2333.0  0.00116  0.00266  0.0997  0.0277           True
# 1    0.0513  0.3423  5962.0  0.00062  0.00558  0.0779  0.0106           True
# 2    0.0606  0.3439  5962.0  0.00091  0.00239  0.0650  0.0123           True
# 3    0.1054  0.3137  7258.0  0.00215  0.00123  0.0212  0.0365           True
# 4    0.1058  0.3183  7258.0  0.00409  0.00029  0.0203  0.0385           True
#
#             sst        sst1  ...  err_sst  err_sst1  err_sst2  flg_sst  \
# obs                          ...
# 0    293.884003  293.907013  ...    0.019     0.042     0.044        5
# 1    293.808990  293.899994  ...    0.023     0.031     0.044        5
# 2    293.756989  293.885986  ...    0.025     0.023     0.037        5
# 3    293.725006  293.868988  ...    0.024     0.017     0.029        5
# 4    293.697998  293.850006  ...    0.021     0.014     0.022        5
#
# ...

# %% [markdown]
# ## Bench test 1: Geographical binning of any variable
# Bins statistic of kinetic energy of all drifters of the dataset.

# %%
# %%time

lon = np.linspace(-180, 180, 360*2)
lat = np.linspace(-90, 90, 180*2)

ret = stats.binned_statistic_2d(df.longitude, 
                                df.latitude, 
                                0.5*np.sqrt(np.power(df.ve, 2) + np.power(df.vn, 2)), # KE
                                statistic=np.nanmean, # can pass any function()
                                bins=[lon, lat])
# Out:
# CPU times: user 2min 1s, sys: 28.2 s, total: 2min 29s
# Wall time: 2min 35s

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid') # what is this for? 
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,aspect='equal')
pcm = ax.pcolormesh(x_c, y_c, ret.statistic.T, vmin=0, vmax=0.5)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.02, axes_class=plt.Axes)
fig.colorbar(pcm, cax=cax);

# %% [markdown]
# ## Bench test 2: Extract a given region

# %%
def retrieve_region_pd(df, lon: list = None, lat: list = None, time: list = None):
    mask = functools.reduce(np.logical_and, 
                            (
                                df.longitude > lon[0], 
                                df.longitude < lon[1],
                                df.latitude > lat[0],
                                df.latitude < lat[1],
                                df.time > day0,
                                df.time < day1,
                            )
                           )
    
    # this should work but crashes the kernel applying the where()
    return df.loc[mask]

# %%
# %%time

lon = [-98, -78]
lat = [18, 31]
day0 = datetime(2015,1,1)
day1 = datetime(2020,12,31)
time = [day0, day1]
df_subset = retrieve_region_pd(df, lon, lat, time)
# Out:
# CPU times: user 2.3 s, sys: 3.78 s, total: 6.07 s
# Wall time: 6.87 s

# %%
df_subset.head()
# Out:
#              ve      vn     gap  err_lat  err_lon  err_ve  err_vn  \
# obs
# 2909297  0.9168 -0.2091  6134.0  0.00158  0.00314  0.0378  0.0279
# 2909298  0.9245 -0.2115  5789.0  0.00100  0.00277  0.0409  0.0278
# 2909299  0.9377 -0.2107  5789.0  0.00260  0.00362  0.0383  0.0340
# 2909300  0.8747 -0.2839  4061.0  0.00186  0.00314  0.0517  0.0283
# 2909301  0.8516 -0.2739  5616.0  0.00128  0.00126  0.0115  0.0223
#
#          drogue_status         sst        sst1  ...  err_sst  err_sst1  \
# obs                                             ...
# 2909297          False  294.431000  294.895996  ...    0.051     0.121
# 2909298          False  294.386993  294.851013  ...    0.049     0.083
# 2909299          False  294.428986  294.808014  ...    0.049     0.059
# 2909300          False  294.541992  294.774994  ...    0.048     0.044
# 2909301          False  294.700012  294.752014  ...    0.047     0.035
#
#          err_sst2  flg_sst  flg_sst1  flg_sst2  longitude   latitude  \
# obs
# ...

# %% [markdown]
# ## Bench test 3: Statistics for one trajectory

# %%
df[df['ids'] == 2578].mean(numeric_only=False) # this is super slow
# Out:
# ve                                    0.016376
# vn                                   -0.037559
# gap                                6657.133789
# err_lat                               0.002503
# err_lon                               0.004255
# err_ve                                     0.0
# err_vn                                     0.0
# drogue_status                         0.995912
# sst                                 285.425415
# sst1                                285.427887
# sst2                                 -0.002436
# err_sst                               0.059197
# err_sst1                              0.020229
# err_sst2                              0.053005
# flg_sst                               4.917072
# flg_sst1                                 4.927
# flg_sst2                              4.338135
# longitude                           -51.361526
# latitude                             43.663841
# time             2005-07-31 20:00:00.000000128
# ...

# %% [markdown]
# The `groupby` operation can be applied to the `ids['obs']` variable to group trajectory together and apply operation per group. There is a set of predefined operation, such as `mean()`, but any functions can be apply using `.apply()` demonstrated below. @philippemiron: maybe explain that this is specific to pandas?

# %%
# %%time
df.groupby("ids").sst.mean()
# Out:
# CPU times: user 3.24 s, sys: 4.3 s, total: 7.53 s
# Wall time: 10.4 s
# ids
# 2578        285.425415
# 2582        283.875000
# 2583               NaN
# 2592        275.799561
# 2612        280.003937
#                ...
# 68249260    284.647736
# 68310100    293.225861
# 68313240    288.159882
# 68318210    287.978882
# 68604340    300.194458
# Name: sst, Length: 17324, dtype: float32

# %%
# %%time

a = df.groupby("ids").sst.apply(lambda x: np.nanmean(x)) # lambda or regular function can be passed # what is lambda?
# Out:
# <timed exec>:1: RuntimeWarning: Mean of empty slice
# CPU times: user 9.46 s, sys: 3.5 s, total: 13 s
# Wall time: 13.3 s

# %% [markdown]
# The results is a dictionnary where the keys are the drifters' id:

# %%
drifter_id = 68249260
a[drifter_id]
# Out:
# 284.64774

# %% [markdown]
# and we can also access by index using the `iloc` indexers:

# %%
a.iloc[np.where(a.index == drifter_id)]
# Out:
# ids
# 68249260    284.647736
# Name: sst, dtype: float32

# %%
del df  # free the memory

# %% [markdown]
# # III. Awkward arrays
# [Awkward Array](https://awkward-array.readthedocs.io/en/latest/) is a library for nested, variable-sized data, including arbitrary-length lists, records, mixed types, and missing data, using NumPy-like idioms. Arrays are dynamically typed, but operations on them are compiled and fast. Their behavior coincides with NumPy when array dimensions are regular and generalizes when they’re not.
#
# The main advantages of awkward array are:
# - the indexing is already taken care of by the library, e.g. sst[400] returns the sea surface temperature along the 401$^{st}$ trajectory;
# - ability to efficiently perform operations per trajectory;
# - easy integration with numba.

# %%
ds_ak = ak.from_parquet("data/gdp_v2.00.parquet")

# %% [markdown]
# Awkward arrays supports N-dimensional datasets by storing nested array. The main dataset contains variable with size `(17324 x type)` containing the metadata

# %%
ds_ak.fields  # list of fields/vars
# Out:
# ['ID',
#  'rowsize',
#  'location_type',
#  'WMO',
#  'expno',
#  'deploy_date',
#  'deploy_lat',
#  'deploy_lon',
#  'end_date',
#  'end_lat',
#  'end_lon',
#  'drogue_lost_date',
#  'type_death',
#  'CurrentProgram',
#  'ManufactureYear',
#  'ManufactureMonth',
#  'ManufactureVoltage',
#  'FloatDiameter',
#  'SubsfcFloatPresence',
#  'DrogueLength',
#  'DrogueBallast',
#  'DragAreaAboveDrogue',
#  'DragAreaOfDrogue',
#  'DragAreaRatio',
#  'DrogueCenterDepth',
#  'obs']

# %%
ds_ak.ID # one variable
# Out:
# <Array [101143, 101144, ... 9929867, 9929870] type='17324 * int64'>

# %% [markdown]
# The obs variable is actually a nested awkward array and contains all variables with size `(17324 x var x type)` observed data along trajectory.

# %%
ds_ak.obs
# Out:
# <Array [{longitude: [-17.7, -17.7, ... 0, 0]}] type='17324 * {"longitude": var *...'>

# %%
print(f'Length of the variables inside obs are {int(ds_ak.obs.longitude.layout.nbytes / 4):,}.') # float32 = 4 bytes
# Out:
# Length of the variables inside obs are 165,771,658.

# %%
ds_ak.obs.fields  # subvariables
# Out:
# ['longitude',
#  'latitude',
#  'time',
#  'ids',
#  've',
#  'vn',
#  'gap',
#  'err_lat',
#  'err_lon',
#  'err_ve',
#  'err_vn',
#  'drogue_status',
#  'sst',
#  'sst1',
#  'sst2',
#  'err_sst',
#  'err_sst1',
#  'err_sst2',
#  'flg_sst',
#  'flg_sst1',
#  'flg_sst2']

# %% [markdown]
# ## Bench test 1: Geographical binning of any variable
# Bins statistic of kinetic energy of all drifters of the dataset.
# @philippemiron: I like the KE but let's start with something simpler, like binning the zonal or meridional velocity or the SST

# %%
# %%time
# can we save the processing time(s) as a variable to later compare to other formats?
lon = np.linspace(-180, 180, 360 * 2)
lat = np.linspace(-90, 90, 180 * 2)

ret = stats.binned_statistic_2d(ak.flatten(ds_ak.obs.longitude, axis=1), 
                                ak.flatten(ds_ak.obs.latitude, axis=1), 
                                ak.flatten(0.5*np.sqrt(np.power(ds_ak.obs.ve, 2) + np.power(ds_ak.obs.vn, 2)), axis=1), # KE
                                statistic=np.nanmean,
                                bins=[lon, lat])
# Out:
# CPU times: user 1min 52s, sys: 11.5 s, total: 2min 3s
# Wall time: 2min 3s

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,aspect='equal')
pcm = ax.pcolormesh(x_c, y_c, ret.statistic.T, vmin=0, vmax=0.5)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.02, axes_class=plt.Axes)
fig.colorbar(pcm, cax=cax);

# %% [markdown]
# ## Bench test 2: Extracting a given region

# %%
def retrieve_region_ak(ds, lon: list = None, lat: list = None, time: list = None):
    
    mask = functools.reduce(np.logical_and, 
                            (
                                ds.longitude > lon[0], 
                                ds.longitude < lon[1],
                                ds.latitude > lat[0],
                                ds.latitude < lat[1],
                                ds.time > day0,
                                ds.time < day1,
                            )
                           )
    
    keep = np.sum(mask == True, axis=1) > 0
    return ds[mask][keep]

# %%
# %%time

lon = [-98, -78]
lat = [18, 31]
day0 = (datetime(2015,1,1) - datetime(1970,1,1)).total_seconds()
day1 = (datetime(2020,12,31) - datetime(1970,1,1)).total_seconds()
time = [day0, day1]
ds_subset = retrieve_region_ak(ds_ak.obs, lon, lat, time)

# %%
ds_subset
# Out:
# <Array [{longitude: [-87.5, -87.5, ... 5, 0]}] type='202 * {"longitude": var * f...'>

# %% [markdown]
# ## Bench test 3: Single statistic per trajectory

# %% [markdown]
# Without the need of indices, we can perform reduce operation per trajectory directly with Awkward array. *Note: the dataset `ds_ak` is loaded in memory here, which explains the speed of the operations. For larger dataset, this would require more steps to interface with Dask.*

# %%
# %%time

m = np.zeros(len(ds_ak.obs))
for i, s in enumerate(ds_ak.obs.sst):
    m[i] = np.nanmean(s)
# Out:
# /Users/pmiron/miniconda3/envs/research/lib/python3.9/site-packages/awkward/_connect/_numpy.py:36: RuntimeWarning: Mean of empty slice
#   out = func(*args, **kwargs)
# CPU times: user 5.61 s, sys: 1.03 s, total: 6.64 s
# Wall time: 6.67 s

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1)

ax.hist(m-273, 100)
ax.set_xlim(-5,32)
ax.set_xlabel('Mean Temperature per trajectory [˚C]')
ax.set_ylabel('Trajectories');

# %% [markdown]
# ## Numba

# %% [markdown]
# Awkward array can be combined with Numba to accelerate calculations.

# %%
@nb.jit
def fft_per_traj(uv):
    d = []
    for i in range(0, len(uv)):
        d.append(np.fft.fft(uv[i]))
    return d

# %%
# %%time

r = fft_per_traj(
    ds_ak.obs.ve + ds_ak.obs.vn*1j
)
# Out:
# /var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_17364/3112511978.py:1: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "fft_per_traj" failed type inference due to: non-precise type pyobject
# During: typing of argument at /var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_17364/3112511978.py (3)
#
# File "../../../../../../../var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_17364/3112511978.py", line 3:
# <source missing, REPL/exec in use?>
#
#   @nb.jit
# /var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_17364/3112511978.py:1: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "fft_per_traj" failed type inference due to: Cannot determine Numba type of <class 'numba.core.dispatcher.LiftedLoop'>
#
# File "../../../../../../../var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_17364/3112511978.py", line 4:
# ...

# %% [markdown]
# each element of the list `r` now contains `fft(u + iv)` per trajectory:

# %%
r[:5]
# Out:
# [<Array [...] type='417 * complex128'>,
#  <Array [...] type='2005 * complex128'>,
#  <Array [...] type='1970 * complex128'>,
#  <Array [...] type='1307 * complex128'>,
#  <Array [...] type='4646 * complex128'>]

# %%
del ds_ak

# %% [markdown]
# # Extra notes in the EarthCube templates

# %% [markdown]
# # Parameter definitions
# Set all relevant parameters for the notebook. By convention, parameters are uppercase, while all the other variables follow Python's guidelines.

# %% [markdown]
# # Data import
# Retrieve all the required data for the analysis. Include brief data descriptions, and DOIs where possible.
#
# Please import data in one of two ways:
# 1. Reference data that is available online and continuously managed (preferred).
# 2. If the data is relatively small, please include the files along with the notebook. If you deal with large data, include a subset.

# %% [markdown]
# # Data processing and analysis
# The core of the notebook is here. Split this section into subsections as required, and explain processing and analysis steps.
#
# Selected best practices for organizing and formatting your notebooks are included below.

# %% [markdown]
# ## The 10 rules
# These recommendations are based on [6]
#
# 1. Tell a story for an audience: interleave explanatory text with code and results to create a computational narrative.
#
# 2. Document the process, not just the results: so that others, and yourself later, will understand your reasoning and choices.
#
# 3. Use cell divisions to make steps clear: have eaach cell perform one meaningful and documented step, avoid long cells.
#
# 4. Modularize code: use and document functions for repeated operations to make the code more readable and save space.
#
# 5. Record dependencies: use pip or Conda package manager, with environment.yml (Conda) or requirements.txt (pip). Please indicate package versions explicitly. Ideally, include a listing of dependencies at the bottom of the notebook. Make sure you test your notebook in an environment created from these dependencies, so that you don't add undocumened dependencies.
#
# 6. Use version control: https://github.com/jupyter/nbdime is a diffing tool specifically designed for notebooks; you may find it useful.
#
# 7. Build a pipeline: place key variable declarations at the top. Test with different parameters, clean up, and run all cells to prepare for potential non-interactive execution.
#
# 8. Share and explain your data: if the original data are too big, inlude a sample. Make sure that the data is accessible. Include data description, and any processing done beforehand. Ideally, point to datasets that have been permanently managed and identified by DOIs.
#
# 9. Design your notebooks to be read, run, and explored:
#     9.1. Read: store it in a public code repository with a clear README file and a liberal open source license. Generate HTML/PDF versions of the final notebook.
#     9.2. Run: use Binder to run it in the cloud, and/or create a Docker image.
#     9.3. Explore: use interactive widgets (e.g., ipywidgets, or panel)
#
# 10. Advocate for open research: ask your colleagues or friends to try to run your notebooks.
#
#
# __Additional recommendations, beyond the 10 rules:__
# 1. Do not include shell commands in cells (unless the notebook will be distributed in Docker container.)
# 2. Keep cell output if other researchers will use the included data, or clear cell output if they will use their own data.
# 3. Develop your code in a clean virtual environment, to avoid dependency conflicts and streamline packaging.
#
# To create a virtual environment, use
# ```
# conda create -n <enviroment_name> python=3 jupyter -y
# ```
# or
# ```
# python3 -m venv /path/to/new/virtual/environment
# ```
# and then activate it. See more about creating virtual environments in [9], [10].
#
# For additional useful guides see [1], [2], [3], [4]

# %% [markdown]
# ## Adding table of contents
#
# Having a table of contents below the title and authors will make your notebook look more professional, and will help users navigate it.
#
# The key steps are:
# 1. In terminal, install jupyter_contrib_nbextensions
# ```
# pip install --user jupyter_contrib_nbextensions
# jupyter contrib nbextension install --user
# ```
#
# 2. Then, enable the Table of Contents extension:
# ```
# jupyter nbextension enable toc2/main
# ```
#
# You will see a new icon "Table of Contents" added to the row of icons. It will toggle the ToC view. Click the Gear icon on the ToC panel to add a ToC cell to your notebook.
#
# See [5.1], [5.2] for more information

# %% [markdown]
# ## Creating Binder and Docker for your notebook repository
#
# Sharing just the Jupyter notebook .ipynb file is not sufficient for broad re-usability. We strongly recommend that Jupyter notebooks are submitted to EarthCube in Binders. The Binder service is a free service that allows anyone to run notebooks from their web browser without installing any software and resolving dependencies.
#
# Follow these steps:
#  - Assemble the Jupyter notebooks , environment files, custom external libraries, datasets, and a README, in a single project directory (and sub-directories off of it, as needed). Use GitHub to organize your project as a GitHub repository.
#
#
#  - Create Binder. Use http://mybinder.org to create a  URL for your notebook Binder (you will need to enter your GitHub repo URL). You can also add a Launch Binder button directly to your GitHub repo, by including the following in your README.md:
#
# ```
# launch with myBinder
# [![Binder](https://mybinder.org/badge.svg)](https://mybinder.org/v2/gh/<path to your repo>)
# ```
#
# Specific projects may have their own Binder implementations. In this case, include a project-specific Binder reference so that reviewers can execute your code.
#
#  - Optionally, test your project with repo2docker. See instructions in [2]. This will create a docker image which can be made available in a Docker repository.
#
#
# Expect the reviewers to use a browser of their choice to run your code, and try to avoid special execution requirements that make it difficult for users to appreciate your work.

# %% [markdown]
# # References
# List relevant references.
#
# -
