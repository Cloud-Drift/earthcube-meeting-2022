# %% [markdown]
# # Accelerating Lagrangian analyses of oceanic data: benchmarking typical workflows

# %% [markdown]
# ## Authors
#
# - Author1 = {"name": "Miron, Philippe", "affiliation": "Florida State University", "email": "pmiron@fsu.edu", "orcid": "0000-0002-8520-6221"}
# - Author2 = {"name": "Elipot, Shane", "affiliation": "University of Miami", "email": "selipot@miami.edu", "orcid": "0000-0001-6051-5426 "}
# - Author3 = {"name": "Lumpkin, Rick", "affiliation": "NOAA’s Atlantic Oceanographic and Meteorological Laboratory", "email": "rick.lumpkin@noaa.gov", "orcid": "0000-0002-6690-1704 "}
# - Author4 = {"name": "Dano, Bertrand", "affiliation": "NOAA’s Atlantic Oceanographic and Meteorological Laboratory", "email": "danob@miami.edu", "orcid": ""}

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc">
#     <ul class="toc-item">
#         <li>
#             <span>
#                 <a href="#Accelerating-Lagrangian-analyses-of-oceanic-data:-benchmarking-typical-workflows" data-toc-modified-id="Accelerating Lagrangian analyses of oceanic data: benchmarking typical workflows">
#                     <span class="toc-item-num">1.&nbsp;</span>Accelerating Lagrangian analyses of oceanic data: benchmarking typical workflows
#                 </a>
#             </span>
#             <ul class="toc-item">
#                 <li>
#                     <span>
#                         <a href="#Author(s)" data-toc-modified-id="Author(s)"><span class="toc-item-num">1.1&nbsp;</span>Author(s)</a>
#                     </span>
#                 </li>
#             </ul>
#         </li>
#         <li>
#             <span>
#                 <a href="#Table-of-Content" data-toc-modified-id="Table of Content"> <span class="toc-item-num">2.&nbsp;</span>Table of Content </a>
#             </span>
#         </li>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Purpose" data-toc-modified-id="Purpose"><span class="toc-item-num">2.1&nbsp;</span>Purpose</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Technical-contributions" data-toc-modified-id="Technical-contributions"><span class="toc-item-num">2.2&nbsp;</span>Technical contributions</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Methodology" data-toc-modified-id="Methodology"><span class="toc-item-num">2.4&nbsp;</span>Methodology</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Results" data-toc-modified-id="Results"><span class="toc-item-num">2.4&nbsp;</span>Results</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Funding" data-toc-modified-id="Funding"><span class="toc-item-num">2.5&nbsp;</span>Funding</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Keywords" data-toc-modified-id="Keywords"><span class="toc-item-num">2.6&nbsp;</span>Keywords</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Citation" data-toc-modified-id="Citation"><span class="toc-item-num">2.7&nbsp;</span>Citation</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Suggested-next-steps" data-toc-modified-id="Suggested-next-steps"><span class="toc-item-num">2.8&nbsp;</span>Suggested next steps</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Acknowledgements" data-toc-modified-id="Acknowledgements.11"><span class="toc-item-num">2.9&nbsp;</span>Acknowledgements</a>
#                 </span>
#             </li>
#         </ul>
#         <li>
#             <span>
#                 <a href="#Setup" data-toc-modified-id="Setup"><span class="toc-item-num">3.&nbsp;</span>Setup</a>
#             </span>
#         </li>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Library-import" data-toc-modified-id="Library-import"><span class="toc-item-num">3.1&nbsp;</span>Library import</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Local-library-import" data-toc-modified-id="Local-library-import"><span class="toc-item-num">3.2&nbsp;</span>Local library import</a>
#                 </span>
#             </li>
#         </ul>
#         <li>
#             <span>
#                 <a href="#Data-Overview" data-toc-modified-id="Data Overview"><span class="toc-item-num">4.&nbsp;</span>Data Overview</a>
#             </span>
#         </li>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Individual-netCDFs" data-toc-modified-id="Individual netCDFs"><span class="toc-item-num">4.1&nbsp;</span>Individual netCDFs</a>
#                 </span>
#             </li>
#             <ul class="toc-item">
#               <li>
#                   <span>
#                       <a href="#Dimensions" data-toc-modified-id="Dimensions"><span class="toc-item-num">4.1.1&nbsp;</span>Dimensions</a>
#                   </span>
#               </li>
#               <li>
#                   <span>
#                       <a href="#Variables" data-toc-modified-id="Variables"><span class="toc-item-num">4.1.2&nbsp;</span>Variables</a>
#                   </span>
#               </li>
#             </ul>
#             <li>
#                 <span>
#                     <a href="#Ragged-Array" data-toc-modified-id="Ragged Array"><span class="toc-item-num">4.2&nbsp;</span>Ragged Array</a>
#                 </span>
#             </li>
#         </ul>
#         <li>
#         <span>
#             <a href="#Xarray" data-toc-modified-id="Xarray"><span class="toc-item-num">5.&nbsp;</span>Xarray</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Xarray-test-1:-Geographical-binning-of-any-variable" data-toc-modified-id="Xarray test 1: Geographical binning of any variable"><span class="toc-item-num">5.1&nbsp;</span>Xarray test 1: Geographical binning of any variable</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Xarray-test-2:-Extract-a-given-region" data-toc-modified-id="Xarray test 2: Extract a given region"><span class="toc-item-num">5.2&nbsp;</span>Xarray test 2: Extract a given region</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Xarray-test-3:-Single-statistic-per-trajectory" data-toc-modified-id="Xarray test 3: Single statistic per trajectory"><span class="toc-item-num">5.3&nbsp;</span>Xarray test 3: Single statistic per trajectory</a>
#                 </span>
#             </li>
#             <li>
#         <span>
#             <a href="#Operation-per-trajectory" data-toc-modified-id="Operation per trajectory"><span class="toc-item-num">5.4.&nbsp;</span>Operation per trajectory</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Simple-operation-by-chunks-(or-blocks)" data-toc-modified-id="Simple operation by chunks (or blocks)"><span class="toc-item-num">5.4.1&nbsp;</span>Simple operation by chunks (or blocks)</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#More-complex-operation-where-dimensions-can-change-between-input-and-output" data-toc-modified-id="More complex operation where dimensions can change between input and output"><span class="toc-item-num">5.4.2&nbsp;</span>More complex operation where dimensions can change between input and output</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#         </ul>
#         </li>
#         <li>
#         <span>
#             <a href="#Pandas" data-toc-modified-id="Pandas"><span class="toc-item-num">6.&nbsp;</span>Pandas</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Pandas-test-1:-Geographical-binning-of-any-variable" data-toc-modified-id="Pandas test 1: Geographical binning of any variable"><span class="toc-item-num">6.1&nbsp;</span>Pandas test 1: Geographical binning of any variable</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Pandas-test-2:-Extract-a-given-region" data-toc-modified-id="Pandas test 2: Extract a given region"><span class="toc-item-num">6.2&nbsp;</span>Pandas test 2: Extract a given region</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Pandas-test-3:-Single-statistic-per-trajectory" data-toc-modified-id="Pandas test 3: Single statistic per trajectory"><span class="toc-item-num">6.3&nbsp;</span>Pandas test 3: Single statistic per trajectory</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#         <li>
#         <span>
#             <a href="#Awkward-Array" data-toc-modified-id="Awkward Array"><span class="toc-item-num">7.&nbsp;</span>Awkward Array</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Awkward-Array-test-1:-Geographical-binning-of-any-variable" data-toc-modified-id="Awkward Array test 1: Geographical binning of any variable"><span class="toc-item-num">7.1&nbsp;</span>Awkward Array test 1: Geographical binning of any variable</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Awkward-Array-test-2:-Extract-a-given-region" data-toc-modified-id="Awkward Array test 2: Extract a given region"><span class="toc-item-num">7.2&nbsp;</span>Awkward Array test 2: Extract a given region</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Awkward-Array-test-3:-Single-statistic-per-trajectory" data-toc-modified-id="Awkward Array test 3: Single statistic per trajectory"><span class="toc-item-num">7.3&nbsp;</span>Awkward Array test 3: Single statistic per trajectory</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Numba" data-toc-modified-id="Numba"><span class="toc-item-num">7.4&nbsp;</span>Numba</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#         <li>
#         <span>
#             <a href="#Discussion" data-toc-modified-id="Discussion"><span class="toc-item-num">8.&nbsp;</span>Discussion</a>
#         </span>
#         <ul class="toc-item">
#             <li>
#                 <span>
#                     <a href="#Benchmark-speed" data-toc-modified-id="Benchmark speed"><span class="toc-item-num">8.1&nbsp;</span>Benchmark speed</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Feedback" data-toc-modified-id="Feedback"><span class="toc-item-num">8.2&nbsp;</span>Feedback</a>
#                 </span>
#             </li>
#             <li>
#                 <span>
#                     <a href="#Future-development" data-toc-modified-id="Future development"><span class="toc-item-num">8.3&nbsp;</span>Future development</a>
#                 </span>
#             </li>
#         </ul>
#         </li>
#         <li>
#         <span>
#             <a href="#References" data-toc-modified-id="References"><span class="toc-item-num">9.&nbsp;</span>References</a>
#         </span>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# ## Purpose
#
# For data, *Lagrangian* refers to oceanic and atmosphere information acquired by observing platforms drifting with the flow they are embedded within, but also more broadly refers to the data originating from uncrewed platforms, vehicles, and animals that gather data along their unrestricted but complicated paths. Because such paths traverse both spatial and temporal dimensions, Lagrangian data often convolve spatial and temporal information that cannot always and readily be organized, cataloged, and stored in common data structures and file formats with the help of common libraries and standards. As such, for both data generators and data users, Lagrangian data present challenges that the [CloudDrift](https://github.com/Cloud-Drift) project aims to overcome.
#
# This notebook consists of systematic comparisons and evaluations of workflows for Lagrangian data, using as a basis the velocity and sea surface temperature dataset emanating from the drifting buoys of the [Global Drifter Program](https://www.aoml.noaa.gov/phod/gdp/). Specifically, we consider the interplay between diverse storage file formats ([NetCDF](https://www.unidata.ucar.edu/software/netcdf/), [Parquet](https://github.com/apache/parquet-format)) and the data structure associated with common existing libraries in Python ([xarray](https://docs.xarray.dev/en/stable/), [pandas](https://pandas.pydata.org), and [awkward](https://awkward-array.org/quickstart.html)) in order to test their adequacies for performing three common Lagrangian tasks: (i) binning of a variable on an Eulerian grid (e.g. mean temperature map); (ii) extracting data within given geographical and/or temporal windows; and (iii) analyses per trajectory (e.g. single statistics, Fast Fourier Transforms). Because the CloudDrift project aims at accelerating the use of Lagrangian data for atmospheric, oceanic, and climate sciences, we hope that this notebook will incite the community of users to eventually test it on their own platform and thus provide us with feedback on its ease of use and the intuitiveness of the proposed methods and guide future developments.
#
# ## Technical contributions
#
# - describe the challenge arising from the analysis of large Lagrangian datasets
# - present a data format for Lagrangian analysis
# - compare how established and up-and-coming libraries perform typical Lagrangian operations
#
# ## Methodology
#
# The notebook has three principal goals:
# 1. Describe the Global Drifter Program dataset, currently provided as a collection of 17,324 netCDF files and present a format to store in its entirety in one archive.
#
# 2. Benchmark three libraries—*xarray*, *Pandas*, and *Awkward Array*—on typical Lagrangian workflow tasks such as the geographical nbinning of a variable, the extraction of a given region, and single statistic perform per trajectory.
#
# 3. Present future works for the CloudDrift library, and obtain feedback from the community to guide future development.
#
# ## Results
#
# Do we need this section..

# %% [markdown]
# # Setup
#
# ## Library import

# %%
# Data manipulation
import numpy as np
import xarray as xr
import pandas as pd
import awkward as ak
from scipy import stats

# others
import time
from os.path import isfile, join
from datetime import datetime
import dask
import numba as nb
import functools

# retrieve data
import urllib.request
import concurrent.futures 

# visualization
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
import cmocean

# raw netcdf files contain non standard values that cause warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# default settings visualization
plt.rcParams.update({'font.size': 8, 
                     'xtick.major.pad': 1, 
                     'ytick.major.pad': 1})

# system information
import platform
import psutil

# %% [markdown]
# ## Local library import

# %%
# include local library paths
from preprocess import create_ragged_array, create_ak

# %% [markdown]
# # Data Overview
#
# The first goal of the notebook is to present the current format of the [Global Drifter Program (GDP)](https://www.aoml.noaa.gov/phod/gdp/) dataset, and its transformation into a single archive where each variable is stored in an ragged fashion.
#
# The GDP produces two interpolated datasets of drifter position, velocity and sea surface temperature from more than 20,000 drifters that have been released since 1979. One dataset is at 6-hour resolution ([Hansen and Poulain 1996](http://dx.doi.org/10.1175/1520-0426(1996)013<0900:QCAIOW>2.0.CO;2)) and the other one is at hourly resolution ([Elipot et al. 2016](http://dx.doi.org/10.1002/2016JC011716)). The files, one per drifter identified by its unique identification number (ID), are updated on a quarterly basis and are available via the FTP website of GDP Data Assembly Center.
#
# Our Notebook used a subset of the drifters of the GDP. Set at `subset_nb_drifters = 500`, the number of trajectories is large enough to create an interesting dataset while speeding up the fetching and processing of the data. It is possible to scale this value. The netCDF files are downloaded from the official `ftp` server.

# %%
subset_nb_drifters = 500  # you can scale up/down this number!

# %%
# %%time
# load the complete list of drifter IDs
list_id = pd.read_csv('data/gdp_ids.csv')

# "randomly" select a subset of id
np.random.seed(42)  # reproducible results
subset_id = np.random.choice(list_id.values.flatten(), subset_nb_drifters)

# output folder and official GDP ftp
folder =  'data/raw/'
input_url = 'ftp://ftp.aoml.noaa.gov/phod/pub/lumpkin/hourly/v2.00/netcdf/'

def fetch_netcdf(url, file):
    '''
    Download and save file from the given url (if not present)
    '''
    if not isfile(file):
        req = urllib.request.urlretrieve(url, file)

# ~2min for 500 drifters
with concurrent.futures.ThreadPoolExecutor() as exector:
    # create list of urls and paths
    urls = []
    files = []
    for i in subset_id:
        file = f'drifter_{i}.nc'
        urls.append(join(input_url, file))
        files.append(join(folder, file))
    
    # parallel retriving of individial nc files 
    exector.map(fetch_netcdf, urls, files)
# Out:
# CPU times: user 30.2 ms, sys: 14.4 ms, total: 44.6 ms
# Wall time: 36.2 ms

# %% [markdown]
# ## Individual netCDFs
#
# The Global drifter program organized file by the drifter unique number, its ID. A few times a year, after quality controled, the files are updated and made available to researchers. There are currently a total of 17,324 files.
#
# ### Dimensions
#
# Individual files contains two dimension:
#
# - `['traj']`: 1, one trajectory per file (e.g. `ID`, `deploy_date`, `deploy_lon`, etc.)
# - `['obs']`: X, with X the number of observations along the trajectory (`longitude`, `latitude`, `ve`, `vn`, `sst`, etc.)
#
# ### Variables
#
# There are 20 variables measured (or postprocessed) along the trajectory, their dimension is `['traj', 'obs']` (`traj` = 1 per file). Naturally, metadata such as: the date of deployment, the type of buoy, etc., are constant along the trajectory and are dimension `['traj']`.

# %%
ds = xr.open_dataset(files[0], decode_times=False)
ds
# Out:
# <xarray.Dataset>
# Dimensions:           (traj: 1, obs: 18157)
# Dimensions without coordinates: traj, obs
# Data variables: (12/33)
#     ID                (traj) |S10 ...
#     rowsize           (traj) int32 ...
#     WMO               (traj) float64 ...
#     expno             (traj) float64 ...
#     deploy_date       (traj) float32 ...
#     deploy_lat        (traj) float64 ...
#     ...                ...
#     err_sst           (traj, obs) float64 ...
#     err_sst1          (traj, obs) float64 ...
#     err_sst2          (traj, obs) float64 ...
#     flg_sst           (traj, obs) float64 ...
#     flg_sst1          (traj, obs) float64 ...
#     flg_sst2          (traj, obs) float64 ...
# Attributes: (12/72)
#     title:                      Global Drifter Program hourly drifting buoy c...
#     id:                         Global Drifter Program ID 84158
#     location_type:              Argos
#     wmo_platform_code:          5600506
# ...

# %% [markdown]
# ## Ragged Array
#
# In the GDP dataset, the number of observations varies from `len(['obs'])=13` to `len(['obs'])=66417`. Because of this, it is **highly unefficient** to create a bidimensional datastructure `['traj', 'obs']`, commonly used in numerical Lagrangian Ocean Analysis toolbox such as [Ocean Parcels](https://oceanparcels.org/) and [OpenDrift](https://opendrift.github.io/). For example, the inclusion of hourly fitted sea surface temperature added 9 variables to the dataset (including diurnal, non diurnal, errors and interpolations flag). We can also expect new sensors and/or postprocessing methods will increase the size of the dataset in the future.
#
# For this, reason we propose to combine the data from the individual netCDFs files into a [*contiguous ragged array*](https://cfconventions.org/cf-conventions/cf-conventions.html#_contiguous_ragged_array_representation), to simplify the distribution, decrease metadata redundancies, and efficiently store nonregular (in size) Lagrangian data. The preprocessing tools (`preprocess.py`) also converts to variables some of the Metadata initially stored as attributes in the individual netCDFs. The final structure contains 21 `vars['obs']` and 38 `vars['traj']`.

# %%
if not isfile(join('data', 'gdp_subset.nc')):
    create_ragged_array(files).to_xarray().to_netcdf(join('data', 'gdp_subset.nc'))

# %%
# using the previously downloaded files
ds = xr.open_dataset('data/gdp_subset.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (traj: 500, obs: 4961563)
# Coordinates:
#     ID                     (traj) int64 ...
#     longitude              (obs) float32 ...
#     latitude               (obs) float32 ...
#     time                   (obs) datetime64[ns] ...
#     ids                    (obs) int64 ...
# Dimensions without coordinates: traj, obs
# Data variables: (12/54)
#     rowsize                (traj) int64 ...
#     location_type          (traj) bool ...
#     WMO                    (traj) int32 ...
#     expno                  (traj) int32 ...
#     deploy_date            (traj) datetime64[ns] ...
#     deploy_lon             (traj) float32 ...
#     ...                     ...
#     err_sst                (obs) float32 ...
#     err_sst1               (obs) float32 ...
#     err_sst2               (obs) float32 ...
#     flg_sst                (obs) int8 ...
#     flg_sst1               (obs) int8 ...
#     flg_sst2               (obs) int8 ...
# ...

# %% [markdown]
# In the combined `xarray.Dataset`, the data from the five trajectories are stored one after the other along the `obs` dimension. The size of each trajectory is stored in the `rowsize` variable.

# %%
ds.rowsize
# Out:
# <xarray.DataArray 'rowsize' (traj: 500)>
# array([18157,  5390,  1093, ...,  4303, 28805, 14602])
# Coordinates:
#     ID       (traj) int64 84158 139491 63250280 92885 ... 42905 44813 65709110
# Dimensions without coordinates: traj
# Attributes:
#     long_name:  Number of observations per trajectory
#     units:      -

# %% [markdown]
# The structure of a ragged array is slightly more complex than a two dimensional array but has several advantages:
# - one file for the complete dataset and less storage space than a 2d matrix
# - from the `rowsize` variable it is possible to subset the data per trajectory
# - efficient to perform reduce operation on the full dataset since the data is stored in a continous array.

# %%
del ds

# %% [markdown]
# The second goal of the notebook is to benchmark different data science libraries. The following sections present 3 typical Lagrangian tasks performed respectively with *Xarray*, *Pandas* and *Awkward Array*.

# %% [markdown]
# # *Xarray*

# %%
path_gdp = 'data/gdp_subset.nc'
ds = xr.open_dataset(path_gdp, chunks={}) # chunks={} to automatically select chunks size

# %% [markdown]
# The package [xarray](https://docs.xarray.dev/en/stable/) provides a nice html interface that allows us to quickly scroll to the variables of the `xr.Dataset`, look at its attributes, and get information about the chunk size and the underlying data structure.

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (traj: 500, obs: 4961563)
# Coordinates:
#     ID                     (traj) int64 dask.array<chunksize=(500,), meta=np.ndarray>
#     longitude              (obs) float32 dask.array<chunksize=(4961563,), meta=np.ndarray>
#     latitude               (obs) float32 dask.array<chunksize=(4961563,), meta=np.ndarray>
#     time                   (obs) datetime64[ns] dask.array<chunksize=(4961563,), meta=np.ndarray>
#     ids                    (obs) int64 dask.array<chunksize=(4961563,), meta=np.ndarray>
# Dimensions without coordinates: traj, obs
# Data variables: (12/54)
#     rowsize                (traj) int64 dask.array<chunksize=(500,), meta=np.ndarray>
#     location_type          (traj) bool dask.array<chunksize=(500,), meta=np.ndarray>
#     WMO                    (traj) int32 dask.array<chunksize=(500,), meta=np.ndarray>
#     expno                  (traj) int32 dask.array<chunksize=(500,), meta=np.ndarray>
# ...

# %% [markdown]
# ## *Xarray* test 1: Geographical binning of any variable
# The first test is the bins statistic of meridional velocity of all drifters of the dataset. From the previous cell, we can see that the size of the chunks were automatically set to the size of `obs`.
#
# For this type of operation, the size of the chunks is convenient because the *complete meridional velocity ragged array* will be loaded in memory in one operation. To perform operations per trajectory (shown below), the size of the chunks is set to the lengh of each trajectory, which would require `subset_nb_drifters` operation to load the same data.
#
# Rechunking is required as a function of the operations to perform.

# %%
benchmark_times = np.zeros((3,3))  # 3 benchmark tests for the 3 different processing libraries

# %%
t0 = time.time()

lon = np.linspace(-180, 180, 360*2)
lat = np.linspace(-90, 90, 180*2)

ret = stats.binned_statistic_2d(ds.longitude, 
                                ds.latitude,
                                ds.ve,
                                statistic=np.nanmean, 
                                bins=[lon, lat])

benchmark_times[0,0] = time.time() - t0

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    ret.statistic.T, 
                    cmap=cmocean.cm.balance, 
                    transform=ccrs.PlateCarree(),
                    vmin=-1.25, vmax=1.25)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.05, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax);
cb.ax.set_ylabel('Meridional velocity [m/s]');

# %% [markdown]
# ## *Xarray* test 2: Extract a given region
#
# Extracting a subregion of the dataset is also a very common operation. *Xarray* provides efficient way to apply mask to the data. One important thing to note is that since we have two dimensions, a mask is applied on the `obs` as well as on the `traj` dimensions.

# %%
def retrieve_region(ds, lon: list = None, lat: list = None, time: list = None) -> xr.Dataset:
    '''Subset the dataset for a region in space and time
    
    Args:
        ds: xarray Dataset
        lon: longitude slice of the subregion
        lat: latitude slice of the subregion
        time: tiem slice of the subregion
    
    Returns: 
        ds_subset: Dataset of the subregion
    '''
    mask = np.ones(ds.dims['obs'], dtype='bool')

    if lon:
        mask &= (ds.coords['longitude'] >= lon[0]).values
        mask &= (ds.coords['longitude'] <= lon[1]).values

    if lat:
        mask &= (ds.coords['latitude'] >= lat[0]).values
        mask &= (ds.coords['latitude'] <= lat[1]).values

    if time:
        mask &= (ds.coords['time'] >= np.datetime64(time[0])).values
        mask &= (ds.coords['time'] <= np.datetime64(time[1])).values

    mask_id = np.in1d(ds.ID, np.unique(ds.ids[mask]))
    ds_subset = ds.isel(obs=np.where(mask)[0], traj=np.where(mask_id)[0])

    return ds_subset.compute()

# %%
t0 = time.time()

# we need to record the time for benchmarking in the end
lon = [-98, -78]
lat = [18, 31]
day0 = '%sZ' % datetime(2000,1,1).isoformat()
day1 = '%sZ' % datetime(2020,12,31).isoformat()
days = [day0, day1]
ds_subset = retrieve_region(ds, lon, lat, days)

benchmark_times[0,1] = time.time() - t0
# Out:
# /var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_44069/716990235.py:24: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   mask &= (ds.coords['time'] >= np.datetime64(time[0])).values
# /var/folders/1c/yxtm88b951l0dkrkf13ftcwh0000gq/T/ipykernel_44069/716990235.py:25: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future
#   mask &= (ds.coords['time'] <= np.datetime64(time[1])).values

# %% [markdown]
# The the sea surface temperature in the extracted subregion, the Gulf of Mexico between 2020—2022, is plotted in the next cell.

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,projection=ccrs.PlateCarree())

pcm = ax.scatter(ds_subset.longitude, ds_subset.latitude, 
               s=0.05, c=ds_subset.sst-273.15, transform=ccrs.PlateCarree(),
               cmap=cmocean.cm.thermal)

ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
ax.set_xticks(np.arange(-95, -79, 5), crs=ccrs.PlateCarree())
ax.set_yticks([20, 25, 30], crs=ccrs.PlateCarree())
ax.xaxis.set_major_formatter(LongitudeFormatter())
ax.yaxis.set_major_formatter(LatitudeFormatter())
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='3%', pad=0.02, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax)
cb.set_label('Sea Surface Temperature [˚C]')

# %% [markdown]
# ## *Xarray* test 3: Single statistic per trajectory
# Because ragged arrays are not *officially* supported by *Xarray*, it is necessary to create an array `traj_idx[i]` that contains starting index of the data for the `i`<sup>th</sup> trajectory.

# %%
traj_idx = np.insert(np.cumsum(ds.rowsize.values), 0, 0)

# %% [markdown]
# This allow for example to recuperate the sst variable of a specified `i`<sup>th</sup> trajectory.

# %%
i = 10
ds.sst[slice(traj_idx[i], traj_idx[i+1])]
# Out:
# <xarray.DataArray 'sst' (obs: 31677)>
# dask.array<getitem, shape=(31677,), dtype=float32, chunksize=(31677,), chunktype=numpy.ndarray>
# Coordinates:
#     longitude  (obs) float32 dask.array<chunksize=(31677,), meta=np.ndarray>
#     latitude   (obs) float32 dask.array<chunksize=(31677,), meta=np.ndarray>
#     time       (obs) datetime64[ns] dask.array<chunksize=(31677,), meta=np.ndarray>
#     ids        (obs) int64 dask.array<chunksize=(31677,), meta=np.ndarray>
# Dimensions without coordinates: obs
# Attributes:
#     long_name:  Fitted sea water temperature
#     units:      Kelvin
#     comments:   Estimated near-surface sea water temperature from drifting bu...

# %%
# we can also retrieve all variables of a trajectory with isel
i = 10
ds.isel({'obs': slice(traj_idx[i], traj_idx[i+1]), 'traj': i}).compute()
# Out:
# <xarray.Dataset>
# Dimensions:                (obs: 31677)
# Coordinates:
#     ID                     int64 60288
#     longitude              (obs) float32 9.269 9.266 9.259 ... 2.331 2.351 2.36
#     latitude               (obs) float32 -42.0 -42.0 -41.99 ... -35.08 -35.08
#     time                   (obs) datetime64[ns] 2005-12-04T23:00:00 ... 2009-...
#     ids                    (obs) int64 60288 60288 60288 ... 60288 60288 60288
# Dimensions without coordinates: obs
# Data variables: (12/54)
#     rowsize                int64 31677
#     location_type          bool False
#     WMO                    int32 1700522
#     expno                  int32 7325
#     deploy_date            datetime64[ns] 2005-12-04
#     deploy_lon             float32 9.268
#     ...                     ...
#     err_sst                (obs) float32 0.01 0.011 0.012 ... 0.01 0.011 nan
#     err_sst1               (obs) float32 0.025 0.018 0.014 ... 0.019 0.029 nan
# ...

# %%
# and perform mean() on a set of variables
s_var = ['ve', 'vn', 'gap', 'err_lat', 'err_lon', 'sst', 'sst1', 'sst2', 'err_sst', 'err_sst1', 'err_sst2']
ds.isel({'obs': slice(traj_idx[i], traj_idx[i+1]), 'traj': i})[s_var].mean().compute()
# Out:
# <xarray.Dataset>
# Dimensions:   ()
# Coordinates:
#     ID        int64 60288
# Data variables:
#     ve        float32 -0.01563
#     vn        float32 0.007892
#     gap       float32 5.985e+03
#     err_lat   float32 0.002203
#     err_lon   float32 0.00303
#     sst       float32 293.4
#     sst1      float32 293.4
#     sst2      float32 0.001194
#     err_sst   float32 0.03111
#     err_sst1  float32 0.01068
#     err_sst2  float32 0.02807

# %% [markdown]
# ## Operation per trajectory

# %% [markdown]
# For this type of operations, it is more efficient to reload the dataset by settings the chunks equal to the dimensions of the trajectory.

# %%
rowsize = ds.rowsize.values
ds.close()

# align chunks of the dask array with the length of each individual trajectory
chunk_settings = {'obs': tuple(rowsize.tolist())}

ds = xr.open_dataset('data/gdp_subset.nc', chunks=chunk_settings)

# %% [markdown]
# We can see that variables such as the longitude, are now splitted into `subset_nb_drifters` chunk, which have different size and where the maximum size is indicated in the `Shape` row.

# %%
ds.longitude
# Out:
# <xarray.DataArray 'longitude' (obs: 4961563)>
# dask.array<open_dataset-2cb692920e90c2434b6874229a47b804longitude, shape=(4961563,), dtype=float32, chunksize=(49120,), chunktype=numpy.ndarray>
# Coordinates:
#     longitude  (obs) float32 dask.array<chunksize=(18157,), meta=np.ndarray>
#     latitude   (obs) float32 dask.array<chunksize=(18157,), meta=np.ndarray>
#     time       (obs) datetime64[ns] dask.array<chunksize=(18157,), meta=np.ndarray>
#     ids        (obs) int64 dask.array<chunksize=(18157,), meta=np.ndarray>
# Dimensions without coordinates: obs
# Attributes:
#     long_name:  Longitude
#     units:      degrees_east

# %% [markdown]
# Naturally, now loading a trajectory always require loading *only* one chunk.

# %%
i = 10
ds.longitude.isel({'obs': slice(traj_idx[i], traj_idx[i+1])})
# Out:
# <xarray.DataArray 'longitude' (obs: 31677)>
# dask.array<getitem, shape=(31677,), dtype=float32, chunksize=(31677,), chunktype=numpy.ndarray>
# Coordinates:
#     longitude  (obs) float32 dask.array<chunksize=(31677,), meta=np.ndarray>
#     latitude   (obs) float32 dask.array<chunksize=(31677,), meta=np.ndarray>
#     time       (obs) datetime64[ns] dask.array<chunksize=(31677,), meta=np.ndarray>
#     ids        (obs) int64 dask.array<chunksize=(31677,), meta=np.ndarray>
# Dimensions without coordinates: obs
# Attributes:
#     long_name:  Longitude
#     units:      degrees_east

# %% [markdown]
# ### Simple operation by chunks (or blocks)

# %% [markdown]
# For example, a function that calculates the `mean()`, `min()`, and `max()` of an array `x`. When mapped per trajectory (per blocks or chunks), the results will be combined as such: `[mean_traj_1, min_traj_1, max_traj_1, mean_traj_2, min_traj_2, max_traj_2, ..., mean_traj_n, min_traj_n, max_traj_n]` resulting in an `numpy array` 3 times as long.

# %% [markdown]
# The function is applied to each chunks/blocks here using `map_blocks()`. Note that this requires loading `nb_subset_drifters` chunks and applying the operation.

# %%
# %%time
def func(x):
    return np.array([np.nanmean(x)])

stats_traj = ds.sst.data.map_blocks(func).compute() # apply to sst variable
# Out:
# <timed exec>:2: RuntimeWarning: Mean of empty slice
# CPU times: user 421 ms, sys: 135 ms, total: 556 ms
# Wall time: 447 ms

# %%
stats_traj[:10]
# Out:
# array([278.05322, 290.75906, 298.88388, 295.96826, 301.19922, 300.1726 ,
#        301.55557, 301.3577 , 275.71317, 289.7603 ], dtype=float32)

# %% [markdown]
# ### More complex operation where dimensions can change between input and output

# %% [markdown]
# Similarly, one can use `apply_ufunc` to map a function per chunks. The function is a bit more complex, but gives more flexibility to handle the input/output format of the function.

# %% [markdown]
# In this first example, the Eastward velocity is passed by chunk to the function which will calculate the anomaly per trajectory.
#
# - *Note 1*: the input and output sizes are not modified.
# - *Note 2*: you must passed `ds.ve.data` (which retrieves the underlying dask array) to the function

# %%
def per_chunk_anomaly(array):
    # MUST return an array (https://github.com/dask/dask/issues/8822)
    return array.map_blocks(lambda x: x-np.nanmean(x), chunks=array.chunks)

# %%
# %%time

ret = xr.apply_ufunc(
    per_chunk_anomaly,
    ds.ve.data,  # .data to retrieve the underlying chunked dask array
    input_core_dims=[['obs']],
    output_core_dims=[['obs']],
    dask='allowed'
).compute()
# Out:
# CPU times: user 392 ms, sys: 144 ms, total: 536 ms
# Wall time: 428 ms

# %%
ret
# Out:
# array([ 0.15023611, -0.21216387,  0.13873611, ..., -0.20656991,
#        -0.12846991, -0.11096992], dtype=float32)

# %% [markdown]
# This second example calculates the `mean()` per trajectory. This means that for our datasets consisting of `nb_subset_drifters` chunks, the output will have `nb_subset_drifters` values or 1 value per chunk.

# %%
def per_chunk_mean(array):
    nchunks = len(array.chunks[0])
    output_chunks = ([1] * nchunks,) # 1 value per chunk
    return array.map_blocks(lambda x: np.nanmean(x, keepdims=True), chunks=output_chunks)

# %%
# %%time

ret = xr.apply_ufunc(
    per_chunk_mean,
    ds.ve.data,
    input_core_dims=[['obs']],  # input dimension to the per_block function
    output_core_dims=[['obs']], # output still has one dimension
    exclude_dims=set(['obs']),  # size of x changes so it has to be in the exclude_dims param
    dask='allowed',
).compute()
# Out:
# CPU times: user 473 ms, sys: 141 ms, total: 614 ms
# Wall time: 503 ms

# %%
len(ret)
# Out:
# 500

# %%
ret[:10]
# Out:
# array([ 0.13796388,  0.01444078, -0.3417346 ,  0.02519639,  0.0492806 ,
#        -0.11039879, -0.01894203,  0.09427432,  0.07966294,  0.02365048],
#       dtype=float32)

# %% [markdown]
# A last example, we calculate `fft` on `u+vi` which is a similar step involved in the calculation of *rotary spectrum*. The combinations of `apply_ufunc` and `map_blocks` is pretty powerful and can serve as templates for most processing applied per trajectory.

# %%
ds = ds.assign(cv=ds['ve'] + 1j * ds['vn'])
ds.cv
# Out:
# <xarray.DataArray 'cv' (obs: 4961563)>
# dask.array<add, shape=(4961563,), dtype=complex64, chunksize=(49120,), chunktype=numpy.ndarray>
# Coordinates:
#     longitude  (obs) float32 dask.array<chunksize=(18157,), meta=np.ndarray>
#     latitude   (obs) float32 dask.array<chunksize=(18157,), meta=np.ndarray>
#     time       (obs) datetime64[ns] dask.array<chunksize=(18157,), meta=np.ndarray>
#     ids        (obs) int64 dask.array<chunksize=(18157,), meta=np.ndarray>
# Dimensions without coordinates: obs

# %%
def per_chunk_fft(array):
    return array.map_blocks(lambda x: np.fft.fft(x), chunks=array.chunks)

# %%
t0 = time.time()

ret = xr.apply_ufunc(
    per_chunk_fft,
    ds['cv'].data,
    input_core_dims=[["obs"]],  # input dimension to the per_block function
    output_core_dims=[["obs"]],  # output still has one dimension
    dask='allowed'
).compute()

benchmark_times[0,2] = time.time() - t0

# %% [markdown]
# The return variable is the same length as `ds['cv']`, and is a ragged array of the computed `fft`.

# %%
ret
# Out:
# array([2505.00999923+129.17909985j, -622.90613101-192.28605431j,
#         223.98611242+535.15166281j, ...,   25.14603521+163.65305474j,
#        -167.37835532+186.28934777j,  317.16114162-217.1514497j ])

# %% [markdown]
# At this stage it is necessary to *clear the memory (RAM)* of the python process because in the next step, the data are fully loaded in memory by using Pandas.

# %%
del ds, ds_subset, ret, traj_idx, stats_traj, rowsize, x_c, y_c

# %% [markdown]
# # *Pandas*
#
# The netCDF has two dimensions `[traj]` and `[obs]`, so it can't be read into a two-dimensional  (rows/columns) `pandas.DataFrame()`. We can convert the netCDF ragged array as follow to keep only `vars[obs]`. The disadvantages is that it requires a second dataset with `vars[traj]` (not presented here) to have access to all variables.

# %%
# %%time
df = xr.open_dataset('data/gdp_subset.nc').drop_dims('traj').to_pandas()  # contains the vars[obs]
# Out:
# CPU times: user 437 ms, sys: 563 ms, total: 1 s
# Wall time: 1.08 s

# %% [markdown]
# The data is represented in a two-dimensional format, each row contains one observation, and each variable is associated with a column. A *Pandas* DataFrame is easy to peak, with the `.head()`, `.tail()` functions.

# %%
df.head()
# Out:
#          ve      vn     gap  err_lat  err_lon  err_ve  err_vn  drogue_status  \
# obs
# 0    0.2882 -0.1178  5357.0  0.04744  0.04366  0.4022  0.3338           True
# 1   -0.0742  0.6616  5875.0  0.03358  0.02763  0.3880  0.4619           True
# 2    0.2767 -0.0890  5875.0  0.01299  0.00964  0.3889  0.4737           True
# 3    0.2790 -0.0201  4838.0  0.01089  0.01025  0.1946  0.2130           True
# 4    0.2633 -0.0662  1382.0  0.00126  0.00362  0.1426  0.0379           True
#
#             sst        sst1  ...  err_sst  err_sst1  err_sst2  flg_sst  \
# obs                          ...
# 0    274.786987  274.803986  ...    0.028     0.061     0.048        5
# 1    274.816986  274.800995  ...    0.017     0.041     0.042        5
# 2    274.850006  274.799011  ...    0.015     0.028     0.034        5
# 3    274.875000  274.798004  ...    0.015     0.020     0.026        5
# 4    274.882996  274.798004  ...    0.015     0.014     0.020        5
#
# ...

# %%
print(f'This subset contains {len(np.unique(df.ids))} drifters and {len(df):,} observations.')
# Out:
# This subset contains 495 drifters and 4,961,563 observations.

# %% [markdown]
# ## *Pandas* test 1: Geographical binning of any variable
# Bins statistic of meridional velocity of all drifters of the dataset.

# %%
t0 = time.time()

lon = np.linspace(-180, 180, 360*2)
lat = np.linspace(-90, 90, 180*2)

ret = stats.binned_statistic_2d(df.longitude, 
                                df.latitude, 
                                df.ve,
                                statistic=np.nanmean, # can pass any function()
                                bins=[lon, lat])

benchmark_times[1,0] = time.time() - t0

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    ret.statistic.T, 
                    cmap=cmocean.cm.balance, 
                    transform=ccrs.PlateCarree(),
                    vmin=-1.25, vmax=1.25)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False
# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.05, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax);
cb.ax.set_ylabel('Meridional velocity [m/s]');

# %% [markdown]
# ## *Pandas* test 2: Extract a given region
#
# The extraction of a region is slightly simpler than with *Xarray*, due to the fact that all variables have the `obs` dimension, so the mask can be directly applied.

# %%
def retrieve_region_pd(df, lon: list = None, lat: list = None, time: list = None):
    '''Subset the dataset for a region in space and time
    
    Args:
        df: Pandas DataFrame
        lon: longitude slice of the subregion
        lat: latitude slice of the subregion
        time: tiem slice of the subregion
    
    Returns: 
        ds_subset: Dataset of the subregion
    '''
    mask = functools.reduce(np.logical_and, 
                            (
                                df.longitude > lon[0], 
                                df.longitude < lon[1],
                                df.latitude > lat[0],
                                df.latitude < lat[1],
                                df.time > day0,
                                df.time < day1,
                            )
                           )
    
    # this should work but crashes the kernel applying the where()
    return df.loc[mask]

# %%
t0 = time.time()

lon = [-98, -78]
lat = [18, 31]
day0 = datetime(2000,1,1)
day1 = datetime(2020,12,31)
days = [day0, day1]
df_subset = retrieve_region_pd(df, lon, lat, days)

benchmark_times[1,1] = time.time() - t0

# %%
df_subset.head()
# Out:
#             ve      vn     gap  err_lat  err_lon  err_ve  err_vn  \
# obs
# 390203 -0.1734  0.1389  5875.0  0.00108  0.00066  0.0111  0.0179
# 390204 -0.1740  0.1383  5875.0  0.00036  0.00019  0.0104  0.0167
# 390205 -0.1723  0.2239  5962.0  0.00122  0.00181  0.0997  0.0444
# 390206 -0.1750  0.2349  5962.0  0.00296  0.00692  0.1049  0.0448
# 390207 -0.0717  0.2646  2333.0  0.00472  0.00742  0.3443  0.0851
#
#         drogue_status         sst        sst1  ...  err_sst  err_sst1  \
# obs                                            ...
# 390203           True  300.113007  300.207001  ...    0.011     0.032
# 390204           True  300.087006  300.175995  ...    0.013     0.020
# 390205           True  300.071014  300.153015  ...    0.014     0.014
# 390206           True  300.058014  300.136993  ...    0.013     0.010
# 390207           True  300.046997  300.123993  ...    0.012     0.008
#
#         err_sst2  flg_sst  flg_sst1  flg_sst2  longitude   latitude  \
# obs
# ...

# %% [markdown]
# ## *Pandas* test 3: Single statistic per trajectory

# %% [markdown]
# Operation can be applied for specific trajectories by locating the drifter ID by value (`loc`) or by index (`iloc`).

# %%
id_ex = 66299660
df.loc[df['ids'] == id_ex].mean(numeric_only=False)
# Out:
# ve                                    0.017321
# vn                                    0.002452
# gap                                2501.343018
# err_lat                               0.000414
# err_lon                               0.000463
# err_ve                                0.015137
# err_vn                                0.015137
# drogue_status                              1.0
# sst                                  300.03479
# sst1                                300.033234
# sst2                                  0.001566
# err_sst                               0.026522
# err_sst1                              0.009128
# err_sst2                              0.023926
# flg_sst                                    5.0
# flg_sst1                                   5.0
# flg_sst2                              4.500821
# longitude                           -70.081787
# latitude                             26.465454
# time             2019-09-10 15:26:37.620024576
# ...

# %% [markdown]
# The pandas `pd.DataFrame.groupby()` function allows for a way to split the `DataFrame`. Applied to the `ids['obs']` (which repeat the ID of a drifter for each of its observations), we can obtain a grouped object containg one trajectory per group. Following this operation, one can applied a predefined set of operations, such as `mean()`, or any user defined functions using `.apply()` demonstrated below.

# %%
# %%time
ret = df.groupby("ids").sst.mean()
ret
# Out:
# CPU times: user 79.8 ms, sys: 16.9 ms, total: 96.8 ms
# Wall time: 96.6 ms
# ids
# 8099        300.414703
# 16978       280.119385
# 17153       288.526642
# 18678       290.742249
# 18743       278.046143
#                ...
# 68242990    274.240051
# 68243260    273.632355
# 68245630    274.302338
# 68246590           NaN
# 68248260    295.535095
# Name: sst, Length: 495, dtype: float32

# %%
def fft_per_group(array):
    return np.fft.fft(array)

# %%
t0 = time.time()

ret = df.groupby("ids").sst.apply(fft_per_group)

benchmark_times[1,2] = time.time() - t0

# %% [markdown]
# The results is is stored into dictionnary where the keys are the drifters' id:

# %%
ret[id_ex][:10]
# Out:
# array([ 2.92473915e+06-1.36424205e-11j, -1.23984495e+04-1.23582377e+03j,
#         2.03575922e+03+1.97905577e+03j, -5.80337756e+02+8.04759996e+01j,
#        -1.13636184e+03+4.87472806e+02j,  1.25114402e+03+2.19800388e+02j,
#         1.76813860e+03-4.87908067e+02j,  4.71820337e+02-1.10371973e+03j,
#         6.48775997e+02-6.19518990e+02j, -1.08115395e+02-7.88630930e+02j])

# %% [markdown]
# and we can also access by index using the `iloc` indexers for a specific drifter:

# %%
ret.iloc[np.where(ret.index == id_ex)]
# Out:
# ids
# 66299660    [(2924739.1450195312-1.3642420526593924e-11j),...
# Name: sst, dtype: object

# %%
del df, df_subset, ret, x_c, y_c  # again free the memory before the next section

# %%
offset = ak.layout.Index32([0,1,4,6])

# %%
ak.layout.ListOffsetArray32(offset, ak.layout.NumpyArray(data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [55], in <module>
# ----> 1 ak.layout.ListOffsetArray32(offset, ak.layout.NumpyArray(data))
#
# NameError: name 'data' is not defined

# %%
ak.from_numpy(data)

# %%
ak.layout.RegularArray?

# %%
ak.layout.NumpyArray(data)

# %%
ak.from_numpy(data)

# %%
import numpy as np
import awkward as ak


def create_ak(data, name):
    array = ak.Array(
            ak.layout.RecordArray(
                [
                   ak.from_numpy(data, highlevel=False)
                ],
                [
                    name
                ]
            )
    )
    return array

a = create_ak(data, 'string')
a

# %%
offset

# %% [markdown]
# # *Awkward Array*
# [*Awkward Array*](https://awkward-array.readthedocs.io/en/latest/) is a library for nested, variable-sized data, including arbitrary-length lists, records, mixed types, and missing data, using NumPy-like idioms. Arrays are dynamically typed, but operations on them are compiled and fast. Their behavior coincides with NumPy when array dimensions are regular and generalizes when they’re not.
#
# The main advantages of awkward array are:
# - the indexing is already taken care of by the library, e.g. sst[400] returns the sea surface temperature along the 401$^{st}$ trajectory;
# - ability to efficiently perform operations per trajectory;
# - easy integration with numba.

# %%
ds_ak = create_ak(xr.open_dataset('data/gdp_subset.nc', decode_times=False))

# %% [markdown]
# *Awkward Arrays* supports N-dimensional datasets by storing nested array. The main dataset contains variables `(type = subset_nb_drifters * {various type})` containing the metadata.

# %%
ds_ak

# %% [markdown]
# *Awkward Array* doesn't (yet!) have an html representation of its structure, but it is possible to list the fields.

# %%
ds_ak.fields  # list of fields/vars

# %% [markdown]
# If we peak inside one of the variable, we can see the associated `type`. For example, the drifters' ID have `type=subset_nb_drifters * int64`.

# %%
ds_ak.ID # one variable

# %% [markdown]
# The obs variable is a nested *Awkward Array* and contains all variables with `type=(subset_nb_drifters * var * dtype)` containing data along trajectories.

# %%
ds_ak.obs

# %% [markdown]
# The library includes the function `ak.flatten()`, similar to `np.flatten()` to concatenate all observations into a unidimensional array.

# %%
print(f'Length of the variables inside obs are {len(ak.flatten(ds_ak.obs.sst)):,}.')
ak.flatten(ds_ak.obs.sst)

# %% [markdown]
# A nested structure is utilized to efficiently store N-dimensional dataset, in our case we first have the `vars['traj']`, followed by the `vars['obj']` in `ds_ak.obs`.

# %%
ds_ak.obs.fields

# %% [markdown]
# Metadata or attributes are also store for the global Array, as well as for each individual variable (similarly to *Xarray*). Those attributes are stored as a parameter in the layout, which summarizes the data fields, the types, the shapes to the data itself.

# %%
ds_ak.layout.parameters['attrs']

# %%
ds_ak.ID.layout.parameters

# %% [markdown]
# For example, the type of the `sst` field, stored at `ds_ak.obs.sst`, is `17324 * var * float32`. This means that there are 17324 trajectories of var*iable* size of float32`.

# %%
ds_ak.obs.sst

# %% [markdown]
# The data along the trajectory of a specific drifter can be easily retrieve using an index. Similarly, specific data points can be retrived using double indices.

# %%
id_ex = 10
ds_ak.obs.sst[id_ex]

# %%
ds_ak.obs.sst[id_ex][0]

# %% [markdown]
# ## *Awkward Array* test 1: Geographical binning of any variable
# Bins statistic of meridional velocity of all drifters of the dataset.

# %%
t0 = time.time()

# can we save the processing time(s) as a variable to later compare to other formats?
lon = np.linspace(-180, 180, 360 * 2)
lat = np.linspace(-90, 90, 180 * 2)

ret = stats.binned_statistic_2d(ak.flatten(ds_ak.obs.longitude, axis=1), 
                                ak.flatten(ds_ak.obs.latitude, axis=1), 
                                ak.flatten(ds_ak.obs.ve, axis=1),
                                statistic=np.nanmean,
                                bins=[lon, lat])
        
benchmark_times[2,0] = time.time() - t0

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    ret.statistic.T, 
                    cmap=cmocean.cm.balance, 
                    transform=ccrs.PlateCarree(),
                    vmin=-1.25, vmax=1.25)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False
# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.05, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax);
cb.ax.set_ylabel('Meridional velocity [m/s]');

# %% [markdown]
# ## *Awkward Array* test 2: Extract a given region

# %%
def retrieve_region_ak(ds: ak.Array, lon: list = None, lat: list = None, time: list = None) -> ak.Array:
    '''Subset the dataset for a region in space and time
    
    Args:
        ds: Awkward Array
        lon: longitude slice of the subregion
        lat: latitude slice of the subregion
        time: tiem slice of the subregion
    
    Returns: 
        ds_subset: Dataset of the subregion
    '''
    mask = functools.reduce(np.logical_and, 
                            (
                                ds.longitude > lon[0], 
                                ds.longitude < lon[1],
                                ds.latitude > lat[0],
                                ds.latitude < lat[1],
                                ds.time > day0,
                                ds.time < day1,
                            )
                           )
    
    keep = np.sum(mask == True, axis=1) > 0
    return ds[mask][keep]

# %%
t0 = time.time()

lon = [-98, -78]
lat = [18, 31]
day0 = (datetime(2000,1,1) - datetime(1970,1,1)).total_seconds()
day1 = (datetime(2020,12,31) - datetime(1970,1,1)).total_seconds()
days = [day0, day1]
ds_subset = retrieve_region_ak(ds_ak.obs, lon, lat, days)

benchmark_times[2,1] = time.time() - t0

# %%
ds_subset

# %% [markdown]
# ## *Awkward Array* test 3: Single statistic per trajectory

# %% [markdown]
# Without the need of indices, we can perform reduce operation per trajectory directly with Awkward array, which simplify considerably the development.
#
# *Note: the dataset `ds_ak` is loaded in memory here, which explains the speed of the operations. For larger dataset, this would require more steps to interface with Dask (those features are currently in development).*

# %%
# %%time

avg_sst = np.zeros(len(ds_ak.obs))
for i, s in enumerate(ds_ak.obs.sst):
    avg_sst[i] = np.nanmean(s)
avg_sst[:10]

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1)

ax.hist(avg_sst-273.15, 100, color='k')
ax.set_xlim(-2, 32)
ax.set_xlabel('Mean Temperature per trajectory [˚C]')
ax.set_ylabel('Trajectories count [-]');

# %% [markdown]
# For basic operation, we can also use *Awkward Array* to perform averages along a specific axis. In our situation, `ak.mean(longitude, axis=1)` perform the same mean operation per trajectory, see that the type is then reduced to `subset_nb_drifters * float64`.
#
# *Note: The `nan` versions of those operations (`nanmean`, `nanstd`, `nanmax`, etc.) is currently not available but should be in the upcoming weeks.*

# %%
avg_lon = ak.mean(ds_ak.obs.longitude, axis=1)
avg_lon

# %% [markdown]
# Applying more complex operation can be easily implemented with simple `for-loop` since the indexing is taken care by *Awkward Array*.

# %%
def fft_per_traj(uv):
    d = []
    for i in range(0, len(uv)):
        d.append(np.fft.fft(uv[i]))
    return d

# %%
t0 = time.time()

ret = fft_per_traj(
    ds_ak.obs.ve + ds_ak.obs.vn*1j
)

benchmark_times[2,2] = time.time() - t0

# %% [markdown]
# each element of the list `ret` now contains `fft(u + iv)` per trajectory:

# %%
ret[:5]

# %% [markdown]
# ## Numba

# %% [markdown]
# *Awkward Array* can be combined with Numba to accelerate calculations. Here, the goal is *not* to show the most efficient way of performing a calculation, but to present how simply adding the numba decorator `@nb.njit` can improved the performance by order of magnitude(s).

# %%
def kinetic_energy(ke, u, v):
    for i in range(0, len(u)-1):
        ke[i] = np.sqrt(u[i]**2 + v[i]**2)
        
@nb.njit
def kinetic_energy_nb(ke, u, v):
    for i in range(0, len(u)-1):
        ke[i] = np.sqrt(u[i]**2 + v[i]**2)

# %%
# select a random trajectory and preallocated the array
id_ex = 10
ke = np.zeros(len(ds_ak.obs.longitude[id_ex]))
ke2 = np.zeros_like(ke)

# %%
# %%time
kinetic_energy(ke, ds_ak.obs.longitude[id_ex], ds_ak.obs.latitude[id_ex])

# %% [markdown]
# The function is compiled just in time when we execute the function for the first time, future executions are *numba fast*.

# %%
kinetic_energy_nb(ke2, ds_ak.obs.longitude[id_ex], ds_ak.obs.latitude[id_ex])

# %%
# %%timeit -r10 -n10
kinetic_energy_nb(ke2, ds_ak.obs.longitude[id_ex], ds_ak.obs.latitude[id_ex])

# %% [markdown]
# This results in more than a 1000x speedup (!) for the same function simply by adding the `@nb.njit` decorators!

# %%
del ds_ak, ret, x_c, y_c

# %% [markdown]
# # Discussion

# %% [markdown]
# We presented the GDP dataset and an efficient structure to combine variables from individual netCDF files into a ragged array. We then compare three different packages–xarray, Pandas, and Awkward Array—by performing typical Lagrangian workflow tasks.
#
# **Xarray**
#
# Xarray is a well known and established package used perform operation on N-Dimensional datasets. It has a great integration with Dask (not demonstrated in details in this Notebook), and allow for *lazy loading* when the dataset is larger than the available memory.
#
# However, it is not typically used with ragged array, so operation per trajectory requires to manually index through the dataset. One possibility, shown in the Xarray section, is to set the size of the Dask *chunks* equals to the size of the trajectories, which allows for mapping operation in parallel per chunk/block/trajectory. Although, the high number of chunks is less than ideal and hinder the performance since a simple `mean` across a dataset containing *n* trajectories requires *n* reading operation.
#
# **Pandas**
#
# Pandas is a predominantly used python data analysis package. It is design to perform operations on a 2-dimensional list (row/columns). To represent the GDP datasets, this would requires two *DataFrame*: one containing the variables with one value per trajectory `vars['traj']`, and a second one containing the variables with one value per observations along the trajectory (`vars['obs']`). This is not a deal-breaker, but nonetheless creates a separation between the metadata and the data.
#
# For this particular Notebook, which consist of a subset of the GDP dataset, the operations are performed *fast* and in a quite elegant and intuitive fashion. Although, our test on the complete dataset where much slower than xarray or Awkward Array which seems to manage memory much more efficiently.
#
# **Awkward Array**
#     - no dask integration (yet!)
#
#
# As part of CloudDrift, we plan on developing functions for Lagrangian analysis, as well as templates to accelerate the creation of *user-specified* functions. To increase efficiency, we will make use of `numba` and fall back to regular `object mode` when the required operations are not supported.
#
# It was developed initally for particle physics applications. Version two is currently in development, and sponsored by [NSF-#2103945](https://www.nsf.gov/awardsearch/showAward?AWD_ID=2103945), and

# %% [markdown]
# ## Benchmark speed

# %% [markdown]
# The following figure present the benchmark times obtain for the current execution. As a comparison, we include a reference time (red dashed line) obtained on a 2021 Mac Mini with a 8 cores Apple M1 ARM processor, 16 GB RAM, running MacOS Monterey 12.3.

# %%
ref_times = np.array([[2.59, 0.48, 0.20],  # [s]
                      [2.54, 0.05, 0.36],
                      [2.57, 0.10, 0.32]])

# %%
fig = plt.figure(dpi=150)
ax = fig.add_subplot(1,1,1)

index = np.arange(0,3)
bar_width = 0.2

t1 = plt.bar(index, benchmark_times[0,:], bar_width,
                 color='violet',
                 label='Xarray')

t2 = plt.bar(index + bar_width, benchmark_times[1,:], bar_width,
                 color='limegreen',
                 label='Pandas')

t3 = plt.bar(index + 2*bar_width, benchmark_times[2,:], bar_width,
                 color='aqua',
                 label='Awkward Array')

# add reference times
for i in range(0, len(index)):
    x = np.array([index[i], index[i] + bar_width, index[i] + 2*bar_width])
    ax.plot(x, ref_times[:,i], 'k', linewidth=0.75, linestyle='dashed', label='Reference time (Apple M1)')

plt.xlabel('Workflow tests')
plt.ylabel('Elapsed time [s] (lower is better)')
plt.title('Benchmark times per library')
plt.xticks(index + bar_width, ('Binning', 'Subsetting', 'FFT(cv) per trajectory'))
handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), frameon=False)

# %% [markdown]
# ## Feedback

# %% [markdown]
# <div>
# <img src="https://jeffcoespa.org/wp-content/uploads/2020/01/bigstock-We-Want-Your-Feedback-Promotio-321303232-768x591.jpg" width="500"/>
# </div>
#
# If you could spare a few minutes and you would like to help us guide the future development of CloudDrift, share the following to the discussion thread on [Github Discussion](link):
# 1. your comments on the ease of use of Xarray and/or Pandas and/or Awkward Arrays for Lagrangian data analysis;
# 2. the figure of your benchmark timings in the previous cell;
# 2. your system information generated by executing the next cell;
# 4. any other comments!
#
# Thanks!

# %%
# print a summary of the system for log purpose
# inspired from https://stackoverflow.com/a/58420504/1558320
def getSystemInfo():
    info={}
    info['platform']=platform.system()
    info['platform-release']=platform.release()
    info['platform-version']=platform.version()
    info['architecture']=platform.machine()
    info['processor']=platform.processor()
    try:
        info['frequency']=psutil.cpu_freq(percpu=False)
    except:
        info['frequency']='N/A'
    info['cores']=psutil.cpu_count(logical=False)
    info['threads']=psutil.cpu_count(logical=True)
    info['ram']=str(round(psutil.virtual_memory().total / (1024.0 **3)))+" GB"
    return info

getSystemInfo()

# %% [markdown]
# ## Future development

# %% [markdown]
# We hope you will follow the development of [CloudDrift](https://github.com/Cloud-Drift), and encourage everyone to share this Notebook as well as submit feedbacks and comments to team members.

# %% [markdown]
# # References
# - Elipot et al. (2016), "A global surface drifter dataset at hourly resolution", J. Geophys. Res. Oceans, 121, [doi:10.1002/2016JC011716](https://doi.org/10.1002/2016JC011716)
# - Hansen, D. V., & Poulain, P. M. (1996). Quality control and interpolations of WOCE-TOGA drifter data. Journal of Atmospheric and Oceanic Technology, 13(4), 900-909, [doi:10.1175/1520-0426(1996)013%3C0900:QCAIOW%3E2.0.CO;2](https://doi.org/10.1175/1520-0426(1996)013%3C0900:QCAIOW%3E2.0.CO;2)

# %% [markdown]
# # Creating Binder and Docker for your notebook repository
#
# Sharing just the Jupyter notebook .ipynb file is not sufficient for broad re-usability. We strongly recommend that Jupyter notebooks are submitted to EarthCube in Binders. The Binder service is a free service that allows anyone to run notebooks from their web browser without installing any software and resolving dependencies.
#
# Follow these steps:
#  - Assemble the Jupyter notebooks , environment files, custom external libraries, datasets, and a README, in a single project directory (and sub-directories off of it, as needed). Use GitHub to organize your project as a GitHub repository.
#
#
#  - Create Binder. Use http://mybinder.org to create a  URL for your notebook Binder (you will need to enter your GitHub repo URL). You can also add a Launch Binder button directly to your GitHub repo, by including the following in your README.md:
#
# ```
# launch with myBinder
# [![Binder](https://mybinder.org/badge.svg)](https://mybinder.org/v2/gh/<path to your repo>)
# ```
#
# Specific projects may have their own Binder implementations. In this case, include a project-specific Binder reference so that reviewers can execute your code.
#
#  - Optionally, test your project with repo2docker. See instructions in [2]. This will create a docker image which can be made available in a Docker repository.
#
#
# Expect the reviewers to use a browser of their choice to run your code, and try to avoid special execution requirements that make it difficult for users to appreciate your work.
